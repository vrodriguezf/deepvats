# %% [markdown]
# # Getting the embeddings
#
# This notebook gets the embeddings (or latent space) from a multivariate time series
# given by a encoder (e.g., autoencoder)
#
# > It uses sliding window view instead of sliding window for splitting the dataset.

# %% [markdown]
# ## Set-up
# Initial notebook setup and specific debugging and pre-configured cases selection.
# ### VsCode update patch
# Initial notebook setup when using VSCode.

# %%
# This is only needed if the notebook is run in VSCode
import sys
if '--vscode' in sys.argv:
    print("Executing inside vscode")
    import nbs_pipeline.utils.vscode  as vs
    vs.DisplayHandle.update = vs.update_patch

# %% [markdown]
# ### Debugging variables
#
# - `print_flag`. If `True` it adds debbuging messages in those functions that allows so (eg. `get_enc_embeddings`)
# - `reset_kernel`. If `True` it resets the kernel by the end of the execution. Use only in case that memory management is needed.
# - `check_memory_usage`. If `True`, it adds some lines for checking the GPU memmory ussage along the execution.
# - `time_flag`. If `True` it get the execution time along the notebook as well as inside those functions that allows so (eg. `get_enc_embeddings`)

# %%
print_flag = False
reset_kernel = True
check_memory_usage = True
time_flag = True

# %% [markdown]
# ## Main code
# ### Import libraries

# %%
from dvats.all import *
from tsai.data.preparation import prepare_forecasting_data
from tsai.data.validation import get_forecasting_splits
from fastcore.all import *
import wandb
from yaml import load, FullLoader
if check_memory_usage:
    import nbs_pipeline.utils.memory as mem
    import torch 
import utils.config as cfg
# Out:
# /home/macu/env/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/macu/env/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZNK3c107SymBool10guard_boolEPKcl'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# Used mem: 1586
# Used mem: 24576
# Memory Usage: [█-------------------] 6%
# Used mem: 23266
# Used mem: 257575
# Memory Usage: [█-------------------] 9.0%

# %% [markdown]
# ### Initialize and Configurate Artifact

# %%
wandb_api = wandb.Api()

# %%
if check_memory_usage:
    gpu_device = torch.cuda.current_device()
    mem.gpu_memory_status(gpu_device)
# Out:
# Used mem: 1586
# Used mem: 24576
# Memory Usage: [█-------------------] 6%

# %% [markdown]
# #### Get configuration parameters from yml
# > Configuration parameters are obtained from 'config\03-embeddings.yaml'

# %%
config, job_type = cfg.get_artifact_config_embeddings(print_flag = print_flag)
if print_flag: cfg.show_attrdict(config)

# %% [markdown]
# ### Setup W&B artifact

# %%
import os
path = os.path.expanduser("~/work/nbs_pipeline/")
name="03b_embeddings-sliding_window_view"
os.environ["WANDB_NOTEBOOK_NAME"] = path+name+".ipynb"
runname=name
print("runname: "+runname)
# Out:
# runname: 03b_embeddings-sliding_window_view

# %%
run = wandb.init(
    entity      = config.wandb_entity,
    project     = config.wandb_project if config.use_wandb else 'work-nbs', 
    group       = config.wandb_group,
    job_type    = job_type,
    mode        = 'online' if config.use_wandb else 'disabled',
    anonymous   = 'never' if config.use_wandb else 'must',
    config      = config,
    resume      = 'allow',
    name        = runname
)
# Out:
# wandb: Currently logged in as: mi-santamaria. Use `wandb login --relogin` to force relogin
# wandb version 0.16.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/home/macu/work/wandb/run-20231222_113746-o7qzl06j</code>
# Syncing run <strong><a href='https://wandb.ai/mi-santamaria/deepvats/runs/o7qzl06j' target="_blank">03b_embeddings-sliding_window_view</a></strong> to <a href='https://wandb.ai/mi-santamaria/deepvats' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mi-santamaria/deepvats' target="_blank">https://wandb.ai/mi-santamaria/deepvats</a>
#  View run at <a href='https://wandb.ai/mi-santamaria/deepvats/runs/o7qzl06j' target="_blank">https://wandb.ai/mi-santamaria/deepvats/runs/o7qzl06j</a>
# 'stream.Stream' object attribute 'write' is read-only

# %% [markdown]
# ### Get trained model artifact

# %% [markdown]
# ##### Build artifact selector
# Botch to use artifacts offline

# %%
artifacts_gettr = run.use_artifact if config.use_wandb else wandb_api.artifact

# %% [markdown]
# ##### Get the model from W&B
# Restore the encoder model and its associated configuration

# %%
enc_artifact = artifacts_gettr(config.enc_artifact, type='learner')

# %%
if print_flag: enc_artifact.metadata

# %%
print("enc_artifact: "+enc_artifact.name)
# Out:
# enc_artifact: mvp-SWV:v35

# %%
# TODO: This only works when you run it two timeS! WTF?
try:
    enc_learner = enc_artifact.to_obj()
except:
    enc_learner = enc_artifact.to_obj()
# Out:
# wandb:   1 of 1 files downloaded.

# %% [markdown]
# ## Get dataset artifact from W&B
# ### Restore the dataset artifact used for training the encoder.
# > Even if we do not compute the dimensionality reduction over this dataset, we need to know the metadata of the encoder training set, to check that it matches with the dataset that we want to reduce.

# %%
enc_run = enc_artifact.logged_by()
enc_artifact_train = artifacts_gettr(enc_run.config['train_artifact'], type='dataset')
enc_artifact_train.name
# Out:
# 'solar_4_seconds-1m:v0'

# %% [markdown]
# ### Specify the dataset artifact that we want to get the embeddings from
# > If no artifact is defined, the artifact to reduce will be the one used for validate the encoder.

# %%
input_ar_name = ifnone(
    config.input_ar, 
    f'{enc_artifact_train.entity}/{enc_artifact_train.project}/{enc_artifact_train.name}'
)
wandb.config.update({'input_ar': input_ar_name}, allow_val_change=True)
input_ar = artifacts_gettr(input_ar_name)
input_ar.name
# Out:
# 'solar_4_seconds-1m:v0'

# %%
df = input_ar.to_df()

if print_flag: 
    display(df.head())
    print("df ~ ", df.shape)
# Out:
# wandb:   1 of 1 files downloaded.

# %% [markdown]
# ### Split data with Sliding Window

# %%
import time

# %%
w = enc_run.config['w']
if print_flag: print(w)

# %%
if check_memory_usage: mem.gpu_memory_status(gpu_device)
# Out:
# Used mem: 1960
# Used mem: 24576
# Memory Usage: [█-------------------] 8%

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
if time_flag: t_start = time.time()

enc_input, _ = prepare_forecasting_data(df, fcst_history = w)

if time_flag: 
    t_end = time.time()
    t = t_end - t_start
    print("SW start | " , t_start, " | end ", t_end, "total (secs): ", t)

if print_flag: print(enc_input.shape)
# Out:
# SW start |  1703245079.0095303  | end  1703245079.0104752 total (secs):  0.0009448528289794922

# %%
if check_memory_usage: mem.gpu_memory_status(gpu_device)
# Out:
# Used mem: 2008
# Used mem: 24576
# Memory Usage: [█-------------------] 8%

# %% [markdown]
# ### Get embedings

# %%
stride = enc_run.config['stride']
batch_size = enc_run.config['batch_size']
#enc_learner.dls.bs = enc_run.config['batch_size']

# %%
if print_flag:
    print(stride)
    print(batch_size)
    print(enc_input.shape)
    print(enc_artifact.name)

# %%
print(enc_input.shape)
# Out:
# (492249, 1, 900)

# %%
if check_memory_usage: mem.gpu_memory_status(gpu_device)
# Out:
# Used mem: 2008
# Used mem: 24576
# Memory Usage: [█-------------------] 8%

# %%
if time_flag: t_start = time.time()

embs = get_enc_embs_set_stride_set_batch_size_parallel(
    X = enc_input, 
    enc_learn = enc_learner, 
    stride = stride, 
    batch_size = batch_size, 
    cpu=config.cpu, 
    to_numpy=True, 
    print_flag = print_flag,
    time_flag = time_flag,
    chunk_size = 1000,
    check_memory_usage = check_memory_usage
)
if time_flag:
    t_end = time.time()
    t = t_end - t_start
    print("GE start | " , t_start, " | end ", t_end, "total (secs): ", t)
# Out:
# Used mem: 2008
# Used mem: 24576
# Memory Usage: [█-------------------] 8%
# NameErrorTraceback (most recent call last)
# Cell In[27], line 3
#       1 if time_flag: t_start = time.time()
# ----> 3 embs = get_enc_embs_set_stride_set_batch_size_parallel(
#       4     X = enc_input,
#       5     enc_learn = enc_learner,
#       6     stride = stride,
#       7     batch_size = batch_size,
#       8     cpu=config.cpu,
#       9     to_numpy=True,
#      10     print_flag = print_flag,
#      11     time_flag = time_flag,
#      12     chunk_size = 1000,
#      13     check_memory_usage = check_memory_usage
#      14 )
#      15 if time_flag:
#      16     t_end = time.time()
#
# File ~/work/dvats/encoder.py:388, in get_enc_embs_set_stride_set_batch_size_parallel(X, enc_learn, stride, batch_size, module, cpu, average_seq_dim, to_numpy, print_flag, time_flag, chunk_size, check_memory_usage, num_workers)
#     384         print("get_enc_embs_set_stride_set_batch_size | Get acts and grads | available_mem ", total-reserved)
#     385         sys.stdout.flush()
# --> 388 Executor = ProcessPoolExecutor if use_cpu else ThreadPoolExecutor
#     390 if (cpu or ( chunk_size == 0 )):
#     391     with Executor(max_workers=num_workers) as executor:
#
# NameError: name 'use_cpu' is not defined

# %%
# %debug

# %%
if check_memory_usage: mem.gpu_memory_status(gpu_device)

# %%
if config.use_wandb: 
    run.log_artifact(ReferenceArtifact(embs, 'embeddings-SWV', metadata=dict(run.config)), 
                     aliases=f'run-{run.project}-{run.id}')

# %%
run.finish()

# %% [markdown]
# ## Final checks

# %% [markdown]
# ### Check num_inputs = embs
# num_inputs = len(enc_input[::stride]) = enc_input.shape[0]/stride + 1 if extra block = ceil(enc_input.shape[0]/stride
#
# num_embs = embs.shape[0]

# %%
#Dimensions check
num_inputs = np.ceil(enc_input.shape[0]/stride)
num_embs = embs.shape[0]
test_eq(num_inputs, num_embs )
print(num_inputs, num_embs)

# %% [markdown]
# # Free GPU

# %%
if check_memory_usage: mem.gpu_memory_status(gpu_device)

# %%
print("Execution ended")
if reset_kernel:
    import os
    os._exit(00)

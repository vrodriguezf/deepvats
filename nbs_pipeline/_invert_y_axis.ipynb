# %%
# importing numpy and matplotlib
import numpy as np
import matplotlib.pyplot as plt

# creating an x sequence
x = np.linspace(5, 15, 35)

# equation of a straight line
y = 3*x+4

# creating graph space for two graphs
graph, (plot1, plot2) = plt.subplots(1, 2)

# plot1 graph for normal axes
plot1.plot(x, y)
plot1.set_title("Normal Plot")

# plot2 graph for inverted axes
plot2.plot(x, y)
plot2.set_title("Inverted Plot")
#plot2.invert_xaxis()
plot2.invert_yaxis()

# display the graph
graph.tight_layout()
plt.show()

# %%
from matplotlib.gridspec import GridSpec

# %%
# creating an x sequence
x = np.linspace(5, 15, 35)
# equation of a straight line
y = 3*x+4

# creating graph space for two graphs
graph, (ax1, ax2) = plt.subplots(2,1, figsize=(5,20))
scale_factor = 0.5


ax1.plot(x,y)
ax2.plot(x,y)

current_size = graph.get_size_inches()
graph.set_size_inches(current_size*scale_factor)

ax1.set_title("Normal Plot")
ax2.set_title("Inverted Plot")



ax2.invert_yaxis()
# display the graph

graph.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# creating an x sequence
x = np.linspace(5, 15, 35)
# equation of a straight line
y = 3 * x + 4

# Specify the desired width in inches
desired_width = 12

# Create the figure and subplots to get the default aspect ratio
graph, (ax1, ax2) = plt.subplots(2, 1)

# Plot the data
ax1.plot(x, y)
ax2.plot(x, y)

# Set titles
ax1.set_title("Normal Plot")
ax2.set_title("Inverted Plot")

# Invert y-axis for the second plot
ax2.invert_yaxis()

# Get the current size of the figure
current_size = graph.get_size_inches()
current_width, current_height = current_size

# Calculate the aspect ratio of the figure (width / height)
aspect_ratio = current_width / current_height

# Calculate the new height to maintain the aspect ratio
new_height = desired_width / aspect_ratio

# Set the new size of the figure
graph.set_size_inches(desired_width, new_height)

# Adjust layout
graph.tight_layout()

# Display the graph
plt.show()

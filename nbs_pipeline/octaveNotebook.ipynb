% %%
path2add = "~/work/nbs/mplot"
addpath(path2add)
% Out:
% path2add = ~/work/nbs/mplot

% %%
plot([1,2,3],'-o', 'linewidth', 2)

% %%
runsplat(80, [], [], true, true, true, true, 5000)
% Out:
% opción piecewiseSplat
% 1
% Some
% user_patience = 2
% Paciencia aceptada
% AsimMat wey asinma wey
% 10000
% 100
% --- Go SimBat ---
% --- timeSeries defined --
% ------> Rounding error blablabla  -------
% ------ Rounding error blablabla ------->
% ---> ADFG A DG DGB2DGB ---
% ------> Hankel -------
% diag
% 1
% 9901
% row
% 9901
% row
% 9900
% row
% 9899
% row
% 9898
% row
% 9897
% row
% 9896
% row
% 9895
% row
% 9894
% row
% 9893
% row
% 9892
% row
% 9891
% row
% 9890
% row
% 9889
% row
% 9888
% row
% 9887
% row
% 9886
% row
% 9885
% row
% 9884
% row
% 9883
% row
% 9882
% row
% 9881
% row
% 9880
% row
% 9879
% row
% 9878
% row
% 9877
% row
% 9876
% row
% 9875
% row
% 9874
% row
% 9873
% row
% 9872
% row
% 9871
% row
% 9870
% row
% 9869
% row
% 9868
% row
% 9867
% row
% 9866
% row
% 9865
% row
% 9864
% row
% 9863
% row
% 9862
% row
% 9861
% row
% 9860
% row
% 9859
% row
% 9858
% row
% 9857
% row
% 9856
% row
% 9855
% row
% 9854
% row
% 9853
% row
% 9852
% row
% 9851
% row
% 9850
% ...

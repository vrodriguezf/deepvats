# %%
from tsai.all import *
# Out:
# ---------------------------------------------------------------------------
# SettingWithCopyError                      Traceback (most recent call last)
# /tmp/ipykernel_5010/2757183762.py in <module>
# ----> 1 from tsai.all import *
#
# ~/lib/tsai/tsai/all.py in <module>
#       2 from .imports import *
#       3 from .utils import *
# ----> 4 from .data.all import *
#       5 from .losses import *
#       6 from .metrics import *
#
# ~/lib/tsai/tsai/data/all.py in <module>
#       1 from .validation import *
#       2 from .preparation import *
# ----> 3 from .external import *
#       4 from .core import *
#       5 from .unwindowed import *
#
# ~/lib/tsai/tsai/data/external.py in <module>
#      22 except ImportError: from urllib.request import urlretrieve
#      23 import shutil
# ---> 24 from sktime.datasets import load_UCR_UEA_dataset
#      25 from sktime.utils.validation.panel import check_X
#      26 from sktime.utils.data_io import load_from_tsfile_to_dataframe as ts2df
# ...

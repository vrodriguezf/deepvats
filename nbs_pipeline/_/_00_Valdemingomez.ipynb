# %% [markdown]
# # Air analysis in Madrid

# %% [markdown]
# ## Download the datasets

# %%
import requests
import zipfile
import os
import shutil
import pandas as pd

# %%
# URLs
year_url = {
    2024: 'https://datos.madrid.es/egob/catalogo/201200-10306320-calidad-aire-horario.zip',
    2023: 'https://datos.madrid.es/egob/catalogo/201200-10306319-calidad-aire-horario.zip',
    2022: 'https://datos.madrid.es/egob/catalogo/201200-10306318-calidad-aire-horario.zip',
    2021: 'https://datos.madrid.es/egob/catalogo/201200-10306317-calidad-aire-horario.zip',
    2020: 'https://datos.madrid.es/egob/catalogo/201200-10306316-calidad-aire-horario.zip',
    2019: 'https://datos.madrid.es/egob/catalogo/201200-42-calidad-aire-horario.zip',
    2018: 'https://datos.madrid.es/egob/catalogo/201200-10306314-calidad-aire-horario.zip',
    2017: 'https://datos.madrid.es/egob/catalogo/201200-10306313-calidad-aire-horario.zip',
    2016: 'https://datos.madrid.es/egob/catalogo/201200-28-calidad-aire-horario.zip',
    2015: 'https://datos.madrid.es/egob/catalogo/201200-27-calidad-aire-horario.zip',
    2014: 'https://datos.madrid.es/egob/catalogo/201200-26-calidad-aire-horario.zip',
    2013: 'https://datos.madrid.es/egob/catalogo/201200-23-calidad-aire-horario.zip',
    2012: 'https://datos.madrid.es/egob/catalogo/201200-22-calidad-aire-horario.zip',
    2011: 'https://datos.madrid.es/egob/catalogo/201200-21-calidad-aire-horario.zip',
    2010: 'https://datos.madrid.es/egob/catalogo/201200-20-calidad-aire-horario.zip',
    2009: 'https://datos.madrid.es/egob/catalogo/201200-19-calidad-aire-horario.zip',
    2008: 'https://datos.madrid.es/egob/catalogo/201200-18-calidad-aire-horario.zip',
    2007: 'https://datos.madrid.es/egob/catalogo/201200-17-calidad-aire-horario.zip',
    2006: 'https://datos.madrid.es/egob/catalogo/201200-16-calidad-aire-horario.zip',
    2005: "https://datos.madrid.es/egob/catalogo/201200-15-calidad-aire-horario.zip",
    2004: "https://datos.madrid.es/egob/catalogo/201200-14-calidad-aire-horario.zip",
    2003: "https://datos.madrid.es/egob/catalogo/201200-13-calidad-aire-horario.zip",
    2002: "https://datos.madrid.es/egob/catalogo/201200-30-calidad-aire-horario.zip",
    2001: "https://datos.madrid.es/egob/catalogo/201200-29-calidad-aire-horario.zip"
}

# %%
output_dir = "calidad_aire_madrid"
os.makedirs(output_dir, exist_ok=True)

# %%
# Function to delete all contents of a folder
def delete_folder(folder, verbose = 0):
    if verbose > 0: print(f"Deleting {folder} content ")
    for f in os.listdir(folder):
        f_path = os.path.join(folder, f)
        try:
            if verbose > 1: print(f"Delete {f_path}?")
            if os.path.isfile(f_path) or os.path.islink(f_path):
                if verbose > 1: print("Yes")
                os.unlink(f_path)
            elif os.path.isdir(f_path):
                if verbose > 1: print(f"It is a folder! Recursive delet {f_path}")
                delete_folder(f_path)
        except Exception as e:
            print(f'Error deleting {f_path}: {e}')

# Function to delete only .txt files in a folder
def delete_folder_txt_xml(folder, verbose = 0):
    if verbose > 0: print(f"Deleting {folder} content (txt, xml)")
    for f in os.listdir(folder):
        f_path = os.path.join(folder, f)
        try:
            if verbose > 1: print(f"Delete {f_path}?")
            if (os.path.isfile(f_path) or os.path.islink(f_path)) and ( f_path.endswith('.txt') or f_path.endswith('.xml')):
                if verbose > 1: print("Yes")
                os.unlink(f_path)
            elif os.path.isdir(f_path):
                if verbose > 1: print(f"It is a folder! Recursive delet {f_path}")
                delete_folder_txt_xml(f_path, verbose)
            elif verbose > 1: print("No")
        except Exception as e:
            print(f'Error deleting {f_path}: {e}')

# %%
def move_contents(src_dir, dst_dir):
    for item in os.listdir(src_dir):
        s = os.path.join(src_dir, item)
        d = os.path.join(dst_dir, item)
        if os.path.isdir(s):
            shutil.move(s, d)
        else:
            shutil.move(s, dst_dir)
            
def download_and_get_name(url, output_dir, year, verbose=0):
    if verbose > 0: print(f"Downloading from {url} to {output_dir}")
    
    # Crear una carpeta específica para el año
    year_dir = os.path.join(output_dir, f"Anio{year-2000}")
    
    # Vaciar la carpeta de destino
    if os.path.exists(year_dir):
        delete_folder(year_dir)
    os.makedirs(year_dir, exist_ok=True)
    
    # Descargar el archivo
    response = requests.get(url)
    if response.status_code == 200:
        if verbose > 1: print(f"Saving response into a zip")
        zip_file_path = os.path.join(year_dir, "temp_download.zip")
        with open(zip_file_path, "wb") as file:
            file.write(response.content)
        if verbose > 1: print(f"Extracting zip")
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(year_dir)
        if verbose > 1: print(f"Removing temporary zip")
        os.remove(zip_file_path)

        # Mover el contenido de la subcarpeta AnioX a year_dir si existe
        subdirs = [d for d in os.listdir(year_dir) if os.path.isdir(os.path.join(year_dir, d))]
        for subdir in subdirs:
            if subdir.startswith('Anio'):
                move_contents(os.path.join(year_dir, subdir), year_dir)
                shutil.rmtree(os.path.join(year_dir, subdir))
        
        f = year_dir
        if verbose > 0: print(f"Downloaded {f}")
    else:
        print(f"No Downloaded file: {response.status_code}")
    if verbose > 0: print("Deleting txt and xml")
    delete_folder_txt_xml(year_dir, verbose)
    if verbose > 0: print("Download finished")
    return f

# %%
foo_2024 = 'https://datos.madrid.es/egob/catalogo/201200-10306320-calidad-aire-horario.zip'  # URL de ejemplo
foo_2021 = "https://datos.madrid.es/egob/catalogo/201200-10306317-calidad-aire-horario.zip" 
foo_2010 = "https://datos.madrid.es/egob/catalogo/201200-20-calidad-aire-horario.zip"
foo_dir = "calidad_aire_madrid"  # Directorio de destino
foo = download_and_get_name(foo_2024, foo_dir, 2024, verbose = 1)
print(f"Archivo descargado: {foo}")
# Out:
# Downloading from https://datos.madrid.es/egob/catalogo/201200-10306320-calidad-aire-horario.zip to calidad_aire_madrid
# Downloaded calidad_aire_madrid/Anio24
# Deleting txt and xml
# Deleting calidad_aire_madrid/Anio24 content (txt, xml)
# Download finished
# Archivo descargado: calidad_aire_madrid/Anio24

# %%
all_data = pd.DataFrame()
data_path = 'calidad_aire_madrid'
delete_folder(data_path)
for year, url in year_url.items():
    print(f"Downloading {year} data from {url}")
    download_and_get_name(url, data_path, year, verbose = 1)
    try:
        for root, dirs, files in os.walk(data_path):
            print(f"{data_path} - {root} | {dirs} | {files}")
            for file in files:
                print(f"{file}")
                if file.endswith('.csv'):
                    print(f"Add {file} to data")
                    file_path = os.path.join(root, file)
                    yearly_data = pd.read_csv(file_path, sep=';')
                    all_data = pd.concat([all_data, yearly_data], ignore_index=True)
            print(f"Delete {data_path}")
        else:
            print(f"Response error for {year}: {response.status_code}")
    except Exception as e:
        print(f"Could not download {year}. Output_dir: {output_dir}")

# Guardar el DataFrame concatenado en un solo archivo CSV
all_data.to_csv("calidad_aire_madrid_2001_2024.csv", index=False)
# Out:
# Downloading 2024 data from https://datos.madrid.es/egob/catalogo/201200-10306320-calidad-aire-horario.zip
# Downloading from https://datos.madrid.es/egob/catalogo/201200-10306320-calidad-aire-horario.zip to calidad_aire_madrid
# Downloaded calidad_aire_madrid/Anio24
# Deleting txt and xml
# Deleting calidad_aire_madrid/Anio24 content (txt, xml)
# Download finished
# calidad_aire_madrid - calidad_aire_madrid | ['Anio5', 'Anio3', 'Anio15', 'Anio24', 'Anio18', 'Anio13', 'Anio9', 'Anio6', 'Anio22', 'Anio11', '.ipynb_checkpoints', 'Anio12', 'Anio17', 'Anio20', 'Anio16', 'Anio10', 'Anio2', 'Anio4', 'Anio8', 'Anio7', 'Anio19', 'Anio21', 'Anio1', 'Anio14', 'Anio23'] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio5 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio3 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio15 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio24 | [] | ['feb_mo24.csv', 'may_mo24.csv', 'abr_mo24.csv', 'mar_mo24.csv', 'jun_mo24.csv', 'ene_mo24.csv']
# feb_mo24.csv
# Add feb_mo24.csv to data
# may_mo24.csv
# Add may_mo24.csv to data
# abr_mo24.csv
# Add abr_mo24.csv to data
# mar_mo24.csv
# Add mar_mo24.csv to data
# jun_mo24.csv
# Add jun_mo24.csv to data
# ene_mo24.csv
# Add ene_mo24.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio18 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio13 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio9 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio6 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio22 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio11 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/.ipynb_checkpoints | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio12 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio17 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio20 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio16 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio10 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio2 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio4 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio8 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio7 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio19 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio21 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio1 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio14 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio23 | [] | []
# Delete calidad_aire_madrid
# Could not download 2024. Output_dir: calidad_aire_madrid
# Downloading 2023 data from https://datos.madrid.es/egob/catalogo/201200-10306319-calidad-aire-horario.zip
# Downloading from https://datos.madrid.es/egob/catalogo/201200-10306319-calidad-aire-horario.zip to calidad_aire_madrid
# Downloaded calidad_aire_madrid/Anio23
# Deleting txt and xml
# Deleting calidad_aire_madrid/Anio23 content (txt, xml)
# Download finished
# calidad_aire_madrid - calidad_aire_madrid | ['Anio5', 'Anio3', 'Anio15', 'Anio24', 'Anio18', 'Anio13', 'Anio9', 'Anio6', 'Anio22', 'Anio11', '.ipynb_checkpoints', 'Anio12', 'Anio17', 'Anio20', 'Anio16', 'Anio10', 'Anio2', 'Anio4', 'Anio8', 'Anio7', 'Anio19', 'Anio21', 'Anio1', 'Anio14', 'Anio23'] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio5 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio3 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio15 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio24 | [] | ['feb_mo24.csv', 'may_mo24.csv', 'abr_mo24.csv', 'mar_mo24.csv', 'jun_mo24.csv', 'ene_mo24.csv']
# feb_mo24.csv
# Add feb_mo24.csv to data
# may_mo24.csv
# Add may_mo24.csv to data
# abr_mo24.csv
# Add abr_mo24.csv to data
# mar_mo24.csv
# Add mar_mo24.csv to data
# jun_mo24.csv
# Add jun_mo24.csv to data
# ene_mo24.csv
# Add ene_mo24.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio18 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio13 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio9 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio6 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio22 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio11 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/.ipynb_checkpoints | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio12 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio17 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio20 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio16 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio10 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio2 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio4 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio8 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio7 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio19 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio21 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio1 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio14 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio23 | [] | ['sep_mo23.csv', 'ene_mo23.csv', 'nov_mo23.csv', 'jul_mo23.csv', 'oct_mo23.csv', 'ago_mo23.csv', 'abr_mo23.csv', 'may_mo23.csv', 'feb_mo23.csv', 'jun_mo23.csv', 'mar_mo23.csv', 'dic_mo23.csv']
# sep_mo23.csv
# Add sep_mo23.csv to data
# ene_mo23.csv
# Add ene_mo23.csv to data
# nov_mo23.csv
# Add nov_mo23.csv to data
# jul_mo23.csv
# Add jul_mo23.csv to data
# oct_mo23.csv
# Add oct_mo23.csv to data
# ago_mo23.csv
# Add ago_mo23.csv to data
# abr_mo23.csv
# Add abr_mo23.csv to data
# may_mo23.csv
# Add may_mo23.csv to data
# feb_mo23.csv
# Add feb_mo23.csv to data
# jun_mo23.csv
# Add jun_mo23.csv to data
# mar_mo23.csv
# Add mar_mo23.csv to data
# dic_mo23.csv
# Add dic_mo23.csv to data
# Delete calidad_aire_madrid
# Could not download 2023. Output_dir: calidad_aire_madrid
# Downloading 2022 data from https://datos.madrid.es/egob/catalogo/201200-10306318-calidad-aire-horario.zip
# Downloading from https://datos.madrid.es/egob/catalogo/201200-10306318-calidad-aire-horario.zip to calidad_aire_madrid
# Downloaded calidad_aire_madrid/Anio22
# Deleting txt and xml
# Deleting calidad_aire_madrid/Anio22 content (txt, xml)
# Download finished
# calidad_aire_madrid - calidad_aire_madrid | ['Anio5', 'Anio3', 'Anio15', 'Anio24', 'Anio18', 'Anio13', 'Anio9', 'Anio6', 'Anio22', 'Anio11', '.ipynb_checkpoints', 'Anio12', 'Anio17', 'Anio20', 'Anio16', 'Anio10', 'Anio2', 'Anio4', 'Anio8', 'Anio7', 'Anio19', 'Anio21', 'Anio1', 'Anio14', 'Anio23'] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio5 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio3 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio15 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio24 | [] | ['feb_mo24.csv', 'may_mo24.csv', 'abr_mo24.csv', 'mar_mo24.csv', 'jun_mo24.csv', 'ene_mo24.csv']
# feb_mo24.csv
# Add feb_mo24.csv to data
# may_mo24.csv
# Add may_mo24.csv to data
# abr_mo24.csv
# Add abr_mo24.csv to data
# mar_mo24.csv
# Add mar_mo24.csv to data
# jun_mo24.csv
# Add jun_mo24.csv to data
# ene_mo24.csv
# Add ene_mo24.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio18 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio13 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio9 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio6 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio22 | [] | ['jul_mo22.csv', 'may_mo22.csv', 'dic_mo22.csv', 'mar_mo22.csv', 'oct_mo22.csv', 'abr_mo22.csv', 'nov_mo22.csv', 'feb_mo22.csv', 'sep_mo22.csv', 'ago_mo22.csv', 'jun_mo22.csv', 'ene_mo22.csv']
# jul_mo22.csv
# Add jul_mo22.csv to data
# may_mo22.csv
# Add may_mo22.csv to data
# dic_mo22.csv
# Add dic_mo22.csv to data
# mar_mo22.csv
# Add mar_mo22.csv to data
# oct_mo22.csv
# Add oct_mo22.csv to data
# abr_mo22.csv
# Add abr_mo22.csv to data
# nov_mo22.csv
# Add nov_mo22.csv to data
# feb_mo22.csv
# Add feb_mo22.csv to data
# sep_mo22.csv
# Add sep_mo22.csv to data
# ago_mo22.csv
# Add ago_mo22.csv to data
# jun_mo22.csv
# Add jun_mo22.csv to data
# ene_mo22.csv
# Add ene_mo22.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio11 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/.ipynb_checkpoints | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio12 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio17 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio20 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio16 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio10 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio2 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio4 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio8 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio7 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio19 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio21 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio1 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio14 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio23 | [] | ['sep_mo23.csv', 'ene_mo23.csv', 'nov_mo23.csv', 'jul_mo23.csv', 'oct_mo23.csv', 'ago_mo23.csv', 'abr_mo23.csv', 'may_mo23.csv', 'feb_mo23.csv', 'jun_mo23.csv', 'mar_mo23.csv', 'dic_mo23.csv']
# sep_mo23.csv
# Add sep_mo23.csv to data
# ene_mo23.csv
# Add ene_mo23.csv to data
# nov_mo23.csv
# Add nov_mo23.csv to data
# jul_mo23.csv
# Add jul_mo23.csv to data
# oct_mo23.csv
# Add oct_mo23.csv to data
# ago_mo23.csv
# Add ago_mo23.csv to data
# abr_mo23.csv
# Add abr_mo23.csv to data
# may_mo23.csv
# Add may_mo23.csv to data
# feb_mo23.csv
# Add feb_mo23.csv to data
# jun_mo23.csv
# Add jun_mo23.csv to data
# mar_mo23.csv
# Add mar_mo23.csv to data
# dic_mo23.csv
# Add dic_mo23.csv to data
# Delete calidad_aire_madrid
# Could not download 2022. Output_dir: calidad_aire_madrid
# Downloading 2021 data from https://datos.madrid.es/egob/catalogo/201200-10306317-calidad-aire-horario.zip
# Downloading from https://datos.madrid.es/egob/catalogo/201200-10306317-calidad-aire-horario.zip to calidad_aire_madrid
# Downloaded calidad_aire_madrid/Anio21
# Deleting txt and xml
# Deleting calidad_aire_madrid/Anio21 content (txt, xml)
# Download finished
# calidad_aire_madrid - calidad_aire_madrid | ['Anio5', 'Anio3', 'Anio15', 'Anio24', 'Anio18', 'Anio13', 'Anio9', 'Anio6', 'Anio22', 'Anio11', '.ipynb_checkpoints', 'Anio12', 'Anio17', 'Anio20', 'Anio16', 'Anio10', 'Anio2', 'Anio4', 'Anio8', 'Anio7', 'Anio19', 'Anio21', 'Anio1', 'Anio14', 'Anio23'] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio5 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio3 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio15 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio24 | [] | ['feb_mo24.csv', 'may_mo24.csv', 'abr_mo24.csv', 'mar_mo24.csv', 'jun_mo24.csv', 'ene_mo24.csv']
# feb_mo24.csv
# Add feb_mo24.csv to data
# may_mo24.csv
# Add may_mo24.csv to data
# abr_mo24.csv
# Add abr_mo24.csv to data
# mar_mo24.csv
# Add mar_mo24.csv to data
# jun_mo24.csv
# Add jun_mo24.csv to data
# ene_mo24.csv
# Add ene_mo24.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio18 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio13 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio9 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio6 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio22 | [] | ['jul_mo22.csv', 'may_mo22.csv', 'dic_mo22.csv', 'mar_mo22.csv', 'oct_mo22.csv', 'abr_mo22.csv', 'nov_mo22.csv', 'feb_mo22.csv', 'sep_mo22.csv', 'ago_mo22.csv', 'jun_mo22.csv', 'ene_mo22.csv']
# jul_mo22.csv
# Add jul_mo22.csv to data
# may_mo22.csv
# Add may_mo22.csv to data
# dic_mo22.csv
# Add dic_mo22.csv to data
# mar_mo22.csv
# Add mar_mo22.csv to data
# oct_mo22.csv
# Add oct_mo22.csv to data
# abr_mo22.csv
# Add abr_mo22.csv to data
# nov_mo22.csv
# Add nov_mo22.csv to data
# feb_mo22.csv
# Add feb_mo22.csv to data
# sep_mo22.csv
# Add sep_mo22.csv to data
# ago_mo22.csv
# Add ago_mo22.csv to data
# jun_mo22.csv
# Add jun_mo22.csv to data
# ene_mo22.csv
# Add ene_mo22.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio11 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/.ipynb_checkpoints | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio12 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio17 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio20 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio16 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio10 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio2 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio4 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio8 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio7 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio19 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio21 | [] | ['jun_mo21.csv', 'nov_mo21.csv', 'sep_mo21.csv', 'abr_mo21.csv', 'may_mo21.csv', 'ene_mo21.csv', 'oct_mo21.csv', 'jul_mo21.csv', 'dic_mo21.csv', 'ago_mo21.csv', 'feb_mo21.csv', 'mar_mo21.csv']
# jun_mo21.csv
# Add jun_mo21.csv to data
# nov_mo21.csv
# Add nov_mo21.csv to data
# sep_mo21.csv
# Add sep_mo21.csv to data
# abr_mo21.csv
# Add abr_mo21.csv to data
# may_mo21.csv
# Add may_mo21.csv to data
# ene_mo21.csv
# Add ene_mo21.csv to data
# oct_mo21.csv
# Add oct_mo21.csv to data
# jul_mo21.csv
# Add jul_mo21.csv to data
# dic_mo21.csv
# Add dic_mo21.csv to data
# ago_mo21.csv
# Add ago_mo21.csv to data
# feb_mo21.csv
# Add feb_mo21.csv to data
# mar_mo21.csv
# Add mar_mo21.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio1 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio14 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio23 | [] | ['sep_mo23.csv', 'ene_mo23.csv', 'nov_mo23.csv', 'jul_mo23.csv', 'oct_mo23.csv', 'ago_mo23.csv', 'abr_mo23.csv', 'may_mo23.csv', 'feb_mo23.csv', 'jun_mo23.csv', 'mar_mo23.csv', 'dic_mo23.csv']
# sep_mo23.csv
# Add sep_mo23.csv to data
# ene_mo23.csv
# Add ene_mo23.csv to data
# nov_mo23.csv
# Add nov_mo23.csv to data
# jul_mo23.csv
# Add jul_mo23.csv to data
# oct_mo23.csv
# Add oct_mo23.csv to data
# ago_mo23.csv
# Add ago_mo23.csv to data
# abr_mo23.csv
# Add abr_mo23.csv to data
# may_mo23.csv
# Add may_mo23.csv to data
# feb_mo23.csv
# Add feb_mo23.csv to data
# jun_mo23.csv
# Add jun_mo23.csv to data
# mar_mo23.csv
# Add mar_mo23.csv to data
# dic_mo23.csv
# Add dic_mo23.csv to data
# Delete calidad_aire_madrid
# Could not download 2021. Output_dir: calidad_aire_madrid
# Downloading 2020 data from https://datos.madrid.es/egob/catalogo/201200-10306316-calidad-aire-horario.zip
# Downloading from https://datos.madrid.es/egob/catalogo/201200-10306316-calidad-aire-horario.zip to calidad_aire_madrid
# Downloaded calidad_aire_madrid/Anio20
# Deleting txt and xml
# Deleting calidad_aire_madrid/Anio20 content (txt, xml)
# Download finished
# calidad_aire_madrid - calidad_aire_madrid | ['Anio5', 'Anio3', 'Anio15', 'Anio24', 'Anio18', 'Anio13', 'Anio9', 'Anio6', 'Anio22', 'Anio11', '.ipynb_checkpoints', 'Anio12', 'Anio17', 'Anio20', 'Anio16', 'Anio10', 'Anio2', 'Anio4', 'Anio8', 'Anio7', 'Anio19', 'Anio21', 'Anio1', 'Anio14', 'Anio23'] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio5 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio3 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio15 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio24 | [] | ['feb_mo24.csv', 'may_mo24.csv', 'abr_mo24.csv', 'mar_mo24.csv', 'jun_mo24.csv', 'ene_mo24.csv']
# feb_mo24.csv
# Add feb_mo24.csv to data
# may_mo24.csv
# Add may_mo24.csv to data
# abr_mo24.csv
# Add abr_mo24.csv to data
# mar_mo24.csv
# Add mar_mo24.csv to data
# jun_mo24.csv
# Add jun_mo24.csv to data
# ene_mo24.csv
# Add ene_mo24.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio18 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio13 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio9 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio6 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio22 | [] | ['jul_mo22.csv', 'may_mo22.csv', 'dic_mo22.csv', 'mar_mo22.csv', 'oct_mo22.csv', 'abr_mo22.csv', 'nov_mo22.csv', 'feb_mo22.csv', 'sep_mo22.csv', 'ago_mo22.csv', 'jun_mo22.csv', 'ene_mo22.csv']
# jul_mo22.csv
# Add jul_mo22.csv to data
# may_mo22.csv
# Add may_mo22.csv to data
# dic_mo22.csv
# Add dic_mo22.csv to data
# mar_mo22.csv
# Add mar_mo22.csv to data
# oct_mo22.csv
# Add oct_mo22.csv to data
# abr_mo22.csv
# Add abr_mo22.csv to data
# nov_mo22.csv
# Add nov_mo22.csv to data
# feb_mo22.csv
# Add feb_mo22.csv to data
# sep_mo22.csv
# Add sep_mo22.csv to data
# ago_mo22.csv
# Add ago_mo22.csv to data
# jun_mo22.csv
# Add jun_mo22.csv to data
# ene_mo22.csv
# Add ene_mo22.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio11 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/.ipynb_checkpoints | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio12 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio17 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio20 | [] | ['may_mo20.csv', 'feb_mo20.csv', 'oct_mo20.csv', 'jul_mo20.csv', 'ago_mo20.csv', 'jun_mo20.csv', 'sep_mo20.csv', 'mar_mo20.csv', 'abr_mo20.csv', 'nov_mo20.csv', 'dic_mo20.csv', 'ene_mo20.csv']
# may_mo20.csv
# Add may_mo20.csv to data
# feb_mo20.csv
# Add feb_mo20.csv to data
# oct_mo20.csv
# Add oct_mo20.csv to data
# jul_mo20.csv
# Add jul_mo20.csv to data
# ago_mo20.csv
# Add ago_mo20.csv to data
# jun_mo20.csv
# Add jun_mo20.csv to data
# sep_mo20.csv
# Add sep_mo20.csv to data
# mar_mo20.csv
# Add mar_mo20.csv to data
# abr_mo20.csv
# Add abr_mo20.csv to data
# nov_mo20.csv
# Add nov_mo20.csv to data
# dic_mo20.csv
# Add dic_mo20.csv to data
# ene_mo20.csv
# Add ene_mo20.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio16 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio10 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio2 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio4 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio8 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio7 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio19 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio21 | [] | ['jun_mo21.csv', 'nov_mo21.csv', 'sep_mo21.csv', 'abr_mo21.csv', 'may_mo21.csv', 'ene_mo21.csv', 'oct_mo21.csv', 'jul_mo21.csv', 'dic_mo21.csv', 'ago_mo21.csv', 'feb_mo21.csv', 'mar_mo21.csv']
# jun_mo21.csv
# Add jun_mo21.csv to data
# nov_mo21.csv
# Add nov_mo21.csv to data
# sep_mo21.csv
# Add sep_mo21.csv to data
# abr_mo21.csv
# Add abr_mo21.csv to data
# may_mo21.csv
# Add may_mo21.csv to data
# ene_mo21.csv
# Add ene_mo21.csv to data
# oct_mo21.csv
# Add oct_mo21.csv to data
# jul_mo21.csv
# Add jul_mo21.csv to data
# dic_mo21.csv
# Add dic_mo21.csv to data
# ago_mo21.csv
# Add ago_mo21.csv to data
# feb_mo21.csv
# Add feb_mo21.csv to data
# mar_mo21.csv
# Add mar_mo21.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio1 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio14 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio23 | [] | ['sep_mo23.csv', 'ene_mo23.csv', 'nov_mo23.csv', 'jul_mo23.csv', 'oct_mo23.csv', 'ago_mo23.csv', 'abr_mo23.csv', 'may_mo23.csv', 'feb_mo23.csv', 'jun_mo23.csv', 'mar_mo23.csv', 'dic_mo23.csv']
# sep_mo23.csv
# Add sep_mo23.csv to data
# ene_mo23.csv
# Add ene_mo23.csv to data
# nov_mo23.csv
# Add nov_mo23.csv to data
# jul_mo23.csv
# Add jul_mo23.csv to data
# oct_mo23.csv
# Add oct_mo23.csv to data
# ago_mo23.csv
# Add ago_mo23.csv to data
# abr_mo23.csv
# Add abr_mo23.csv to data
# may_mo23.csv
# Add may_mo23.csv to data
# feb_mo23.csv
# Add feb_mo23.csv to data
# jun_mo23.csv
# Add jun_mo23.csv to data
# mar_mo23.csv
# Add mar_mo23.csv to data
# dic_mo23.csv
# Add dic_mo23.csv to data
# Delete calidad_aire_madrid
# Could not download 2020. Output_dir: calidad_aire_madrid
# Downloading 2019 data from https://datos.madrid.es/egob/catalogo/201200-42-calidad-aire-horario.zip
# Downloading from https://datos.madrid.es/egob/catalogo/201200-42-calidad-aire-horario.zip to calidad_aire_madrid
# Downloaded calidad_aire_madrid/Anio19
# Deleting txt and xml
# Deleting calidad_aire_madrid/Anio19 content (txt, xml)
# Download finished
# calidad_aire_madrid - calidad_aire_madrid | ['Anio5', 'Anio3', 'Anio15', 'Anio24', 'Anio18', 'Anio13', 'Anio9', 'Anio6', 'Anio22', 'Anio11', '.ipynb_checkpoints', 'Anio12', 'Anio17', 'Anio20', 'Anio16', 'Anio10', 'Anio2', 'Anio4', 'Anio8', 'Anio7', 'Anio19', 'Anio21', 'Anio1', 'Anio14', 'Anio23'] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio5 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio3 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio15 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio24 | [] | ['feb_mo24.csv', 'may_mo24.csv', 'abr_mo24.csv', 'mar_mo24.csv', 'jun_mo24.csv', 'ene_mo24.csv']
# feb_mo24.csv
# Add feb_mo24.csv to data
# may_mo24.csv
# Add may_mo24.csv to data
# abr_mo24.csv
# Add abr_mo24.csv to data
# mar_mo24.csv
# Add mar_mo24.csv to data
# jun_mo24.csv
# Add jun_mo24.csv to data
# ene_mo24.csv
# Add ene_mo24.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio18 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio13 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio9 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio6 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio22 | [] | ['jul_mo22.csv', 'may_mo22.csv', 'dic_mo22.csv', 'mar_mo22.csv', 'oct_mo22.csv', 'abr_mo22.csv', 'nov_mo22.csv', 'feb_mo22.csv', 'sep_mo22.csv', 'ago_mo22.csv', 'jun_mo22.csv', 'ene_mo22.csv']
# jul_mo22.csv
# Add jul_mo22.csv to data
# may_mo22.csv
# Add may_mo22.csv to data
# dic_mo22.csv
# Add dic_mo22.csv to data
# mar_mo22.csv
# Add mar_mo22.csv to data
# oct_mo22.csv
# Add oct_mo22.csv to data
# abr_mo22.csv
# Add abr_mo22.csv to data
# nov_mo22.csv
# Add nov_mo22.csv to data
# feb_mo22.csv
# Add feb_mo22.csv to data
# sep_mo22.csv
# Add sep_mo22.csv to data
# ago_mo22.csv
# Add ago_mo22.csv to data
# jun_mo22.csv
# Add jun_mo22.csv to data
# ene_mo22.csv
# Add ene_mo22.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio11 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/.ipynb_checkpoints | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio12 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio17 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio20 | [] | ['may_mo20.csv', 'feb_mo20.csv', 'oct_mo20.csv', 'jul_mo20.csv', 'ago_mo20.csv', 'jun_mo20.csv', 'sep_mo20.csv', 'mar_mo20.csv', 'abr_mo20.csv', 'nov_mo20.csv', 'dic_mo20.csv', 'ene_mo20.csv']
# may_mo20.csv
# Add may_mo20.csv to data
# feb_mo20.csv
# Add feb_mo20.csv to data
# oct_mo20.csv
# Add oct_mo20.csv to data
# jul_mo20.csv
# Add jul_mo20.csv to data
# ago_mo20.csv
# Add ago_mo20.csv to data
# jun_mo20.csv
# Add jun_mo20.csv to data
# sep_mo20.csv
# Add sep_mo20.csv to data
# mar_mo20.csv
# Add mar_mo20.csv to data
# abr_mo20.csv
# Add abr_mo20.csv to data
# nov_mo20.csv
# Add nov_mo20.csv to data
# dic_mo20.csv
# Add dic_mo20.csv to data
# ene_mo20.csv
# Add ene_mo20.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio16 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio10 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio2 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio4 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio8 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio7 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio19 | [] | ['abr_mo19.csv', 'ene_mo19.csv', 'ago_mo19.csv', 'sep_mo19.csv', 'may_mo19.csv', 'feb_mo19.csv', 'dic_mo19.csv', 'jun_mo19.csv', 'jul_mo19.csv', 'oct_mo19.csv', 'nov_mo19.csv', 'mar_mo19.csv']
# abr_mo19.csv
# Add abr_mo19.csv to data
# ene_mo19.csv
# Add ene_mo19.csv to data
# ago_mo19.csv
# Add ago_mo19.csv to data
# sep_mo19.csv
# Add sep_mo19.csv to data
# may_mo19.csv
# Add may_mo19.csv to data
# feb_mo19.csv
# Add feb_mo19.csv to data
# dic_mo19.csv
# Add dic_mo19.csv to data
# jun_mo19.csv
# Add jun_mo19.csv to data
# jul_mo19.csv
# Add jul_mo19.csv to data
# oct_mo19.csv
# Add oct_mo19.csv to data
# nov_mo19.csv
# Add nov_mo19.csv to data
# mar_mo19.csv
# Add mar_mo19.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio21 | [] | ['jun_mo21.csv', 'nov_mo21.csv', 'sep_mo21.csv', 'abr_mo21.csv', 'may_mo21.csv', 'ene_mo21.csv', 'oct_mo21.csv', 'jul_mo21.csv', 'dic_mo21.csv', 'ago_mo21.csv', 'feb_mo21.csv', 'mar_mo21.csv']
# jun_mo21.csv
# Add jun_mo21.csv to data
# nov_mo21.csv
# Add nov_mo21.csv to data
# sep_mo21.csv
# Add sep_mo21.csv to data
# abr_mo21.csv
# Add abr_mo21.csv to data
# may_mo21.csv
# Add may_mo21.csv to data
# ene_mo21.csv
# Add ene_mo21.csv to data
# oct_mo21.csv
# Add oct_mo21.csv to data
# jul_mo21.csv
# Add jul_mo21.csv to data
# dic_mo21.csv
# Add dic_mo21.csv to data
# ago_mo21.csv
# Add ago_mo21.csv to data
# feb_mo21.csv
# Add feb_mo21.csv to data
# mar_mo21.csv
# Add mar_mo21.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio1 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio14 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio23 | [] | ['sep_mo23.csv', 'ene_mo23.csv', 'nov_mo23.csv', 'jul_mo23.csv', 'oct_mo23.csv', 'ago_mo23.csv', 'abr_mo23.csv', 'may_mo23.csv', 'feb_mo23.csv', 'jun_mo23.csv', 'mar_mo23.csv', 'dic_mo23.csv']
# sep_mo23.csv
# Add sep_mo23.csv to data
# ene_mo23.csv
# Add ene_mo23.csv to data
# nov_mo23.csv
# Add nov_mo23.csv to data
# jul_mo23.csv
# Add jul_mo23.csv to data
# oct_mo23.csv
# Add oct_mo23.csv to data
# ago_mo23.csv
# Add ago_mo23.csv to data
# abr_mo23.csv
# Add abr_mo23.csv to data
# may_mo23.csv
# Add may_mo23.csv to data
# feb_mo23.csv
# Add feb_mo23.csv to data
# jun_mo23.csv
# Add jun_mo23.csv to data
# mar_mo23.csv
# Add mar_mo23.csv to data
# dic_mo23.csv
# Add dic_mo23.csv to data
# Delete calidad_aire_madrid
# Could not download 2019. Output_dir: calidad_aire_madrid
# Downloading 2018 data from https://datos.madrid.es/egob/catalogo/201200-10306314-calidad-aire-horario.zip
# Downloading from https://datos.madrid.es/egob/catalogo/201200-10306314-calidad-aire-horario.zip to calidad_aire_madrid
# Downloaded calidad_aire_madrid/Anio18
# Deleting txt and xml
# Deleting calidad_aire_madrid/Anio18 content (txt, xml)
# Download finished
# calidad_aire_madrid - calidad_aire_madrid | ['Anio5', 'Anio3', 'Anio15', 'Anio24', 'Anio18', 'Anio13', 'Anio9', 'Anio6', 'Anio22', 'Anio11', '.ipynb_checkpoints', 'Anio12', 'Anio17', 'Anio20', 'Anio16', 'Anio10', 'Anio2', 'Anio4', 'Anio8', 'Anio7', 'Anio19', 'Anio21', 'Anio1', 'Anio14', 'Anio23'] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio5 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio3 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio15 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio24 | [] | ['feb_mo24.csv', 'may_mo24.csv', 'abr_mo24.csv', 'mar_mo24.csv', 'jun_mo24.csv', 'ene_mo24.csv']
# feb_mo24.csv
# Add feb_mo24.csv to data
# may_mo24.csv
# Add may_mo24.csv to data
# abr_mo24.csv
# Add abr_mo24.csv to data
# mar_mo24.csv
# Add mar_mo24.csv to data
# jun_mo24.csv
# Add jun_mo24.csv to data
# ene_mo24.csv
# Add ene_mo24.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio18 | [] | ['jun_mo18.csv', 'mar_mo18.csv', 'ene_mo18.csv', 'jul_mo18.csv', 'abr_mo18.csv', 'sep_mo18.csv', 'nov_mo18.csv', 'oct_mo18.csv', 'ago_mo18.csv', 'dic_mo18.csv', 'feb_mo18.csv', 'may_mo18.csv']
# jun_mo18.csv
# Add jun_mo18.csv to data
# mar_mo18.csv
# Add mar_mo18.csv to data
# ene_mo18.csv
# Add ene_mo18.csv to data
# jul_mo18.csv
# Add jul_mo18.csv to data
# abr_mo18.csv
# Add abr_mo18.csv to data
# sep_mo18.csv
# Add sep_mo18.csv to data
# nov_mo18.csv
# Add nov_mo18.csv to data
# oct_mo18.csv
# Add oct_mo18.csv to data
# ago_mo18.csv
# Add ago_mo18.csv to data
# dic_mo18.csv
# Add dic_mo18.csv to data
# feb_mo18.csv
# Add feb_mo18.csv to data
# may_mo18.csv
# Add may_mo18.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio13 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio9 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio6 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio22 | [] | ['jul_mo22.csv', 'may_mo22.csv', 'dic_mo22.csv', 'mar_mo22.csv', 'oct_mo22.csv', 'abr_mo22.csv', 'nov_mo22.csv', 'feb_mo22.csv', 'sep_mo22.csv', 'ago_mo22.csv', 'jun_mo22.csv', 'ene_mo22.csv']
# jul_mo22.csv
# Add jul_mo22.csv to data
# may_mo22.csv
# Add may_mo22.csv to data
# dic_mo22.csv
# Add dic_mo22.csv to data
# mar_mo22.csv
# Add mar_mo22.csv to data
# oct_mo22.csv
# Add oct_mo22.csv to data
# abr_mo22.csv
# Add abr_mo22.csv to data
# nov_mo22.csv
# Add nov_mo22.csv to data
# feb_mo22.csv
# Add feb_mo22.csv to data
# sep_mo22.csv
# Add sep_mo22.csv to data
# ago_mo22.csv
# Add ago_mo22.csv to data
# jun_mo22.csv
# Add jun_mo22.csv to data
# ene_mo22.csv
# Add ene_mo22.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio11 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/.ipynb_checkpoints | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio12 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio17 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio20 | [] | ['may_mo20.csv', 'feb_mo20.csv', 'oct_mo20.csv', 'jul_mo20.csv', 'ago_mo20.csv', 'jun_mo20.csv', 'sep_mo20.csv', 'mar_mo20.csv', 'abr_mo20.csv', 'nov_mo20.csv', 'dic_mo20.csv', 'ene_mo20.csv']
# may_mo20.csv
# Add may_mo20.csv to data
# feb_mo20.csv
# Add feb_mo20.csv to data
# oct_mo20.csv
# Add oct_mo20.csv to data
# jul_mo20.csv
# Add jul_mo20.csv to data
# ago_mo20.csv
# Add ago_mo20.csv to data
# jun_mo20.csv
# Add jun_mo20.csv to data
# sep_mo20.csv
# Add sep_mo20.csv to data
# mar_mo20.csv
# Add mar_mo20.csv to data
# abr_mo20.csv
# Add abr_mo20.csv to data
# nov_mo20.csv
# Add nov_mo20.csv to data
# dic_mo20.csv
# Add dic_mo20.csv to data
# ene_mo20.csv
# Add ene_mo20.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio16 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio10 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio2 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio4 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio8 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio7 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio19 | [] | ['abr_mo19.csv', 'ene_mo19.csv', 'ago_mo19.csv', 'sep_mo19.csv', 'may_mo19.csv', 'feb_mo19.csv', 'dic_mo19.csv', 'jun_mo19.csv', 'jul_mo19.csv', 'oct_mo19.csv', 'nov_mo19.csv', 'mar_mo19.csv']
# abr_mo19.csv
# Add abr_mo19.csv to data
# ene_mo19.csv
# Add ene_mo19.csv to data
# ago_mo19.csv
# Add ago_mo19.csv to data
# sep_mo19.csv
# Add sep_mo19.csv to data
# may_mo19.csv
# Add may_mo19.csv to data
# feb_mo19.csv
# Add feb_mo19.csv to data
# dic_mo19.csv
# Add dic_mo19.csv to data
# jun_mo19.csv
# Add jun_mo19.csv to data
# jul_mo19.csv
# Add jul_mo19.csv to data
# oct_mo19.csv
# Add oct_mo19.csv to data
# nov_mo19.csv
# Add nov_mo19.csv to data
# mar_mo19.csv
# Add mar_mo19.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio21 | [] | ['jun_mo21.csv', 'nov_mo21.csv', 'sep_mo21.csv', 'abr_mo21.csv', 'may_mo21.csv', 'ene_mo21.csv', 'oct_mo21.csv', 'jul_mo21.csv', 'dic_mo21.csv', 'ago_mo21.csv', 'feb_mo21.csv', 'mar_mo21.csv']
# jun_mo21.csv
# Add jun_mo21.csv to data
# nov_mo21.csv
# Add nov_mo21.csv to data
# sep_mo21.csv
# Add sep_mo21.csv to data
# abr_mo21.csv
# Add abr_mo21.csv to data
# may_mo21.csv
# Add may_mo21.csv to data
# ene_mo21.csv
# Add ene_mo21.csv to data
# oct_mo21.csv
# Add oct_mo21.csv to data
# jul_mo21.csv
# Add jul_mo21.csv to data
# dic_mo21.csv
# Add dic_mo21.csv to data
# ago_mo21.csv
# Add ago_mo21.csv to data
# feb_mo21.csv
# Add feb_mo21.csv to data
# mar_mo21.csv
# Add mar_mo21.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio1 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio14 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio23 | [] | ['sep_mo23.csv', 'ene_mo23.csv', 'nov_mo23.csv', 'jul_mo23.csv', 'oct_mo23.csv', 'ago_mo23.csv', 'abr_mo23.csv', 'may_mo23.csv', 'feb_mo23.csv', 'jun_mo23.csv', 'mar_mo23.csv', 'dic_mo23.csv']
# sep_mo23.csv
# Add sep_mo23.csv to data
# ene_mo23.csv
# Add ene_mo23.csv to data
# nov_mo23.csv
# Add nov_mo23.csv to data
# jul_mo23.csv
# Add jul_mo23.csv to data
# oct_mo23.csv
# Add oct_mo23.csv to data
# ago_mo23.csv
# Add ago_mo23.csv to data
# abr_mo23.csv
# Add abr_mo23.csv to data
# may_mo23.csv
# Add may_mo23.csv to data
# feb_mo23.csv
# Add feb_mo23.csv to data
# jun_mo23.csv
# Add jun_mo23.csv to data
# mar_mo23.csv
# Add mar_mo23.csv to data
# dic_mo23.csv
# Add dic_mo23.csv to data
# Delete calidad_aire_madrid
# Could not download 2018. Output_dir: calidad_aire_madrid
# Downloading 2017 data from https://datos.madrid.es/egob/catalogo/201200-10306313-calidad-aire-horario.zip
# Downloading from https://datos.madrid.es/egob/catalogo/201200-10306313-calidad-aire-horario.zip to calidad_aire_madrid
# Downloaded calidad_aire_madrid/Anio17
# Deleting txt and xml
# Deleting calidad_aire_madrid/Anio17 content (txt, xml)
# Download finished
# calidad_aire_madrid - calidad_aire_madrid | ['Anio5', 'Anio3', 'Anio15', 'Anio24', 'Anio18', 'Anio13', 'Anio9', 'Anio6', 'Anio22', 'Anio11', '.ipynb_checkpoints', 'Anio12', 'Anio17', 'Anio20', 'Anio16', 'Anio10', 'Anio2', 'Anio4', 'Anio8', 'Anio7', 'Anio19', 'Anio21', 'Anio1', 'Anio14', 'Anio23'] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio5 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio3 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio15 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio24 | [] | ['feb_mo24.csv', 'may_mo24.csv', 'abr_mo24.csv', 'mar_mo24.csv', 'jun_mo24.csv', 'ene_mo24.csv']
# feb_mo24.csv
# Add feb_mo24.csv to data
# may_mo24.csv
# Add may_mo24.csv to data
# abr_mo24.csv
# Add abr_mo24.csv to data
# mar_mo24.csv
# Add mar_mo24.csv to data
# jun_mo24.csv
# Add jun_mo24.csv to data
# ene_mo24.csv
# Add ene_mo24.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio18 | [] | ['jun_mo18.csv', 'mar_mo18.csv', 'ene_mo18.csv', 'jul_mo18.csv', 'abr_mo18.csv', 'sep_mo18.csv', 'nov_mo18.csv', 'oct_mo18.csv', 'ago_mo18.csv', 'dic_mo18.csv', 'feb_mo18.csv', 'may_mo18.csv']
# jun_mo18.csv
# Add jun_mo18.csv to data
# mar_mo18.csv
# Add mar_mo18.csv to data
# ene_mo18.csv
# Add ene_mo18.csv to data
# jul_mo18.csv
# Add jul_mo18.csv to data
# abr_mo18.csv
# Add abr_mo18.csv to data
# sep_mo18.csv
# Add sep_mo18.csv to data
# nov_mo18.csv
# Add nov_mo18.csv to data
# oct_mo18.csv
# Add oct_mo18.csv to data
# ago_mo18.csv
# Add ago_mo18.csv to data
# dic_mo18.csv
# Add dic_mo18.csv to data
# feb_mo18.csv
# Add feb_mo18.csv to data
# may_mo18.csv
# Add may_mo18.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio13 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio9 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio6 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio22 | [] | ['jul_mo22.csv', 'may_mo22.csv', 'dic_mo22.csv', 'mar_mo22.csv', 'oct_mo22.csv', 'abr_mo22.csv', 'nov_mo22.csv', 'feb_mo22.csv', 'sep_mo22.csv', 'ago_mo22.csv', 'jun_mo22.csv', 'ene_mo22.csv']
# jul_mo22.csv
# Add jul_mo22.csv to data
# may_mo22.csv
# Add may_mo22.csv to data
# dic_mo22.csv
# Add dic_mo22.csv to data
# mar_mo22.csv
# Add mar_mo22.csv to data
# oct_mo22.csv
# Add oct_mo22.csv to data
# abr_mo22.csv
# Add abr_mo22.csv to data
# nov_mo22.csv
# Add nov_mo22.csv to data
# feb_mo22.csv
# Add feb_mo22.csv to data
# sep_mo22.csv
# Add sep_mo22.csv to data
# ago_mo22.csv
# Add ago_mo22.csv to data
# jun_mo22.csv
# Add jun_mo22.csv to data
# ene_mo22.csv
# Add ene_mo22.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio11 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/.ipynb_checkpoints | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio12 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio17 | [] | ['mar_mo17.csv', 'ago_mo17.csv', 'jun_mo17.csv', 'jul_mo17.csv', 'feb_mo17.csv', 'dic_mo17.csv', 'abr_mo17.csv', 'may_mo17.csv', 'oct_mo17.csv', 'nov_mo17.csv', 'sep_mo17.csv', 'ene_mo17.csv']
# mar_mo17.csv
# Add mar_mo17.csv to data
# ago_mo17.csv
# Add ago_mo17.csv to data
# jun_mo17.csv
# Add jun_mo17.csv to data
# jul_mo17.csv
# Add jul_mo17.csv to data
# feb_mo17.csv
# Add feb_mo17.csv to data
# dic_mo17.csv
# Add dic_mo17.csv to data
# abr_mo17.csv
# Add abr_mo17.csv to data
# may_mo17.csv
# Add may_mo17.csv to data
# oct_mo17.csv
# Add oct_mo17.csv to data
# nov_mo17.csv
# Add nov_mo17.csv to data
# sep_mo17.csv
# Add sep_mo17.csv to data
# ene_mo17.csv
# Add ene_mo17.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio20 | [] | ['may_mo20.csv', 'feb_mo20.csv', 'oct_mo20.csv', 'jul_mo20.csv', 'ago_mo20.csv', 'jun_mo20.csv', 'sep_mo20.csv', 'mar_mo20.csv', 'abr_mo20.csv', 'nov_mo20.csv', 'dic_mo20.csv', 'ene_mo20.csv']
# may_mo20.csv
# Add may_mo20.csv to data
# feb_mo20.csv
# Add feb_mo20.csv to data
# oct_mo20.csv
# Add oct_mo20.csv to data
# jul_mo20.csv
# Add jul_mo20.csv to data
# ago_mo20.csv
# Add ago_mo20.csv to data
# jun_mo20.csv
# Add jun_mo20.csv to data
# sep_mo20.csv
# Add sep_mo20.csv to data
# mar_mo20.csv
# Add mar_mo20.csv to data
# abr_mo20.csv
# Add abr_mo20.csv to data
# nov_mo20.csv
# Add nov_mo20.csv to data
# dic_mo20.csv
# Add dic_mo20.csv to data
# ene_mo20.csv
# Add ene_mo20.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio16 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio10 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio2 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio4 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio8 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio7 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio19 | [] | ['abr_mo19.csv', 'ene_mo19.csv', 'ago_mo19.csv', 'sep_mo19.csv', 'may_mo19.csv', 'feb_mo19.csv', 'dic_mo19.csv', 'jun_mo19.csv', 'jul_mo19.csv', 'oct_mo19.csv', 'nov_mo19.csv', 'mar_mo19.csv']
# abr_mo19.csv
# Add abr_mo19.csv to data
# ene_mo19.csv
# Add ene_mo19.csv to data
# ago_mo19.csv
# Add ago_mo19.csv to data
# sep_mo19.csv
# Add sep_mo19.csv to data
# may_mo19.csv
# Add may_mo19.csv to data
# feb_mo19.csv
# Add feb_mo19.csv to data
# dic_mo19.csv
# Add dic_mo19.csv to data
# jun_mo19.csv
# Add jun_mo19.csv to data
# jul_mo19.csv
# Add jul_mo19.csv to data
# oct_mo19.csv
# Add oct_mo19.csv to data
# nov_mo19.csv
# Add nov_mo19.csv to data
# mar_mo19.csv
# Add mar_mo19.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio21 | [] | ['jun_mo21.csv', 'nov_mo21.csv', 'sep_mo21.csv', 'abr_mo21.csv', 'may_mo21.csv', 'ene_mo21.csv', 'oct_mo21.csv', 'jul_mo21.csv', 'dic_mo21.csv', 'ago_mo21.csv', 'feb_mo21.csv', 'mar_mo21.csv']
# jun_mo21.csv
# Add jun_mo21.csv to data
# nov_mo21.csv
# Add nov_mo21.csv to data
# sep_mo21.csv
# Add sep_mo21.csv to data
# abr_mo21.csv
# Add abr_mo21.csv to data
# may_mo21.csv
# Add may_mo21.csv to data
# ene_mo21.csv
# Add ene_mo21.csv to data
# oct_mo21.csv
# Add oct_mo21.csv to data
# jul_mo21.csv
# Add jul_mo21.csv to data
# dic_mo21.csv
# Add dic_mo21.csv to data
# ago_mo21.csv
# Add ago_mo21.csv to data
# feb_mo21.csv
# Add feb_mo21.csv to data
# mar_mo21.csv
# Add mar_mo21.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio1 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio14 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio23 | [] | ['sep_mo23.csv', 'ene_mo23.csv', 'nov_mo23.csv', 'jul_mo23.csv', 'oct_mo23.csv', 'ago_mo23.csv', 'abr_mo23.csv', 'may_mo23.csv', 'feb_mo23.csv', 'jun_mo23.csv', 'mar_mo23.csv', 'dic_mo23.csv']
# sep_mo23.csv
# Add sep_mo23.csv to data
# ene_mo23.csv
# Add ene_mo23.csv to data
# nov_mo23.csv
# Add nov_mo23.csv to data
# jul_mo23.csv
# Add jul_mo23.csv to data
# oct_mo23.csv
# Add oct_mo23.csv to data
# ago_mo23.csv
# Add ago_mo23.csv to data
# abr_mo23.csv
# Add abr_mo23.csv to data
# may_mo23.csv
# Add may_mo23.csv to data
# feb_mo23.csv
# Add feb_mo23.csv to data
# jun_mo23.csv
# Add jun_mo23.csv to data
# mar_mo23.csv
# Add mar_mo23.csv to data
# dic_mo23.csv
# Add dic_mo23.csv to data
# Delete calidad_aire_madrid
# Could not download 2017. Output_dir: calidad_aire_madrid
# Downloading 2016 data from https://datos.madrid.es/egob/catalogo/201200-28-calidad-aire-horario.zip
# Downloading from https://datos.madrid.es/egob/catalogo/201200-28-calidad-aire-horario.zip to calidad_aire_madrid
# Downloaded calidad_aire_madrid/Anio16
# Deleting txt and xml
# Deleting calidad_aire_madrid/Anio16 content (txt, xml)
# Download finished
# calidad_aire_madrid - calidad_aire_madrid | ['Anio5', 'Anio3', 'Anio15', 'Anio24', 'Anio18', 'Anio13', 'Anio9', 'Anio6', 'Anio22', 'Anio11', '.ipynb_checkpoints', 'Anio12', 'Anio17', 'Anio20', 'Anio16', 'Anio10', 'Anio2', 'Anio4', 'Anio8', 'Anio7', 'Anio19', 'Anio21', 'Anio1', 'Anio14', 'Anio23'] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio5 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio3 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio15 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio24 | [] | ['feb_mo24.csv', 'may_mo24.csv', 'abr_mo24.csv', 'mar_mo24.csv', 'jun_mo24.csv', 'ene_mo24.csv']
# feb_mo24.csv
# Add feb_mo24.csv to data
# may_mo24.csv
# Add may_mo24.csv to data
# abr_mo24.csv
# Add abr_mo24.csv to data
# mar_mo24.csv
# Add mar_mo24.csv to data
# jun_mo24.csv
# Add jun_mo24.csv to data
# ene_mo24.csv
# Add ene_mo24.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio18 | [] | ['jun_mo18.csv', 'mar_mo18.csv', 'ene_mo18.csv', 'jul_mo18.csv', 'abr_mo18.csv', 'sep_mo18.csv', 'nov_mo18.csv', 'oct_mo18.csv', 'ago_mo18.csv', 'dic_mo18.csv', 'feb_mo18.csv', 'may_mo18.csv']
# jun_mo18.csv
# Add jun_mo18.csv to data
# mar_mo18.csv
# Add mar_mo18.csv to data
# ene_mo18.csv
# Add ene_mo18.csv to data
# jul_mo18.csv
# Add jul_mo18.csv to data
# abr_mo18.csv
# Add abr_mo18.csv to data
# sep_mo18.csv
# Add sep_mo18.csv to data
# nov_mo18.csv
# Add nov_mo18.csv to data
# oct_mo18.csv
# Add oct_mo18.csv to data
# ago_mo18.csv
# Add ago_mo18.csv to data
# dic_mo18.csv
# Add dic_mo18.csv to data
# feb_mo18.csv
# Add feb_mo18.csv to data
# may_mo18.csv
# Add may_mo18.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio13 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio9 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio6 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio22 | [] | ['jul_mo22.csv', 'may_mo22.csv', 'dic_mo22.csv', 'mar_mo22.csv', 'oct_mo22.csv', 'abr_mo22.csv', 'nov_mo22.csv', 'feb_mo22.csv', 'sep_mo22.csv', 'ago_mo22.csv', 'jun_mo22.csv', 'ene_mo22.csv']
# jul_mo22.csv
# Add jul_mo22.csv to data
# may_mo22.csv
# Add may_mo22.csv to data
# dic_mo22.csv
# Add dic_mo22.csv to data
# mar_mo22.csv
# Add mar_mo22.csv to data
# oct_mo22.csv
# Add oct_mo22.csv to data
# abr_mo22.csv
# Add abr_mo22.csv to data
# nov_mo22.csv
# Add nov_mo22.csv to data
# feb_mo22.csv
# Add feb_mo22.csv to data
# sep_mo22.csv
# Add sep_mo22.csv to data
# ago_mo22.csv
# Add ago_mo22.csv to data
# jun_mo22.csv
# Add jun_mo22.csv to data
# ene_mo22.csv
# Add ene_mo22.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio11 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/.ipynb_checkpoints | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio12 | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio17 | [] | ['mar_mo17.csv', 'ago_mo17.csv', 'jun_mo17.csv', 'jul_mo17.csv', 'feb_mo17.csv', 'dic_mo17.csv', 'abr_mo17.csv', 'may_mo17.csv', 'oct_mo17.csv', 'nov_mo17.csv', 'sep_mo17.csv', 'ene_mo17.csv']
# mar_mo17.csv
# Add mar_mo17.csv to data
# ago_mo17.csv
# Add ago_mo17.csv to data
# jun_mo17.csv
# Add jun_mo17.csv to data
# jul_mo17.csv
# Add jul_mo17.csv to data
# feb_mo17.csv
# Add feb_mo17.csv to data
# dic_mo17.csv
# Add dic_mo17.csv to data
# abr_mo17.csv
# Add abr_mo17.csv to data
# may_mo17.csv
# Add may_mo17.csv to data
# oct_mo17.csv
# Add oct_mo17.csv to data
# nov_mo17.csv
# Add nov_mo17.csv to data
# sep_mo17.csv
# Add sep_mo17.csv to data
# ene_mo17.csv
# Add ene_mo17.csv to data
# Delete calidad_aire_madrid
# ...
# ago_mo03.csv
# Add ago_mo03.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio15 | [] | ['may_mo15.csv', 'jun_mo15.csv', 'dic_mo15.csv', 'nov_mo15.csv', 'sep_mo15.csv', 'abr_mo15.csv', 'oct_mo15.csv', 'jul_mo15.csv', 'ago_mo15.csv', 'mar_mo15.csv', 'ene_mo15.csv', 'feb_mo15.csv']
# may_mo15.csv
# Add may_mo15.csv to data
# jun_mo15.csv
# Add jun_mo15.csv to data
# dic_mo15.csv
# Add dic_mo15.csv to data
# nov_mo15.csv
# Add nov_mo15.csv to data
# sep_mo15.csv
# Add sep_mo15.csv to data
# abr_mo15.csv
# Add abr_mo15.csv to data
# oct_mo15.csv
# Add oct_mo15.csv to data
# jul_mo15.csv
# Add jul_mo15.csv to data
# ago_mo15.csv
# Add ago_mo15.csv to data
# mar_mo15.csv
# Add mar_mo15.csv to data
# ene_mo15.csv
# Add ene_mo15.csv to data
# feb_mo15.csv
# Add feb_mo15.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio24 | [] | ['feb_mo24.csv', 'may_mo24.csv', 'abr_mo24.csv', 'mar_mo24.csv', 'jun_mo24.csv', 'ene_mo24.csv']
# feb_mo24.csv
# Add feb_mo24.csv to data
# may_mo24.csv
# Add may_mo24.csv to data
# abr_mo24.csv
# Add abr_mo24.csv to data
# mar_mo24.csv
# Add mar_mo24.csv to data
# jun_mo24.csv
# Add jun_mo24.csv to data
# ene_mo24.csv
# Add ene_mo24.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio18 | [] | ['jun_mo18.csv', 'mar_mo18.csv', 'ene_mo18.csv', 'jul_mo18.csv', 'abr_mo18.csv', 'sep_mo18.csv', 'nov_mo18.csv', 'oct_mo18.csv', 'ago_mo18.csv', 'dic_mo18.csv', 'feb_mo18.csv', 'may_mo18.csv']
# jun_mo18.csv
# Add jun_mo18.csv to data
# mar_mo18.csv
# Add mar_mo18.csv to data
# ene_mo18.csv
# Add ene_mo18.csv to data
# jul_mo18.csv
# Add jul_mo18.csv to data
# abr_mo18.csv
# Add abr_mo18.csv to data
# sep_mo18.csv
# Add sep_mo18.csv to data
# nov_mo18.csv
# Add nov_mo18.csv to data
# oct_mo18.csv
# Add oct_mo18.csv to data
# ago_mo18.csv
# Add ago_mo18.csv to data
# dic_mo18.csv
# Add dic_mo18.csv to data
# feb_mo18.csv
# Add feb_mo18.csv to data
# may_mo18.csv
# Add may_mo18.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio13 | [] | ['nov_mo13.csv', 'jun_mo13.csv', 'mar_mo13.csv', 'oct_mo13.csv', 'sep_mo13.csv', 'may_mo13.csv', 'feb_mo13.csv', 'jul_mo13.csv', 'dic_mo13.csv', 'ago_mo13.csv', 'ene_mo13.csv', 'abr_mo13.csv']
# nov_mo13.csv
# Add nov_mo13.csv to data
# jun_mo13.csv
# Add jun_mo13.csv to data
# mar_mo13.csv
# Add mar_mo13.csv to data
# oct_mo13.csv
# Add oct_mo13.csv to data
# sep_mo13.csv
# Add sep_mo13.csv to data
# may_mo13.csv
# Add may_mo13.csv to data
# feb_mo13.csv
# Add feb_mo13.csv to data
# jul_mo13.csv
# Add jul_mo13.csv to data
# dic_mo13.csv
# Add dic_mo13.csv to data
# ago_mo13.csv
# Add ago_mo13.csv to data
# ene_mo13.csv
# Add ene_mo13.csv to data
# abr_mo13.csv
# Add abr_mo13.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio9 | [] | ['sep_mo09.csv', 'jun_mo09.csv', 'feb_mo09.csv', 'nov_mo09.csv', 'mar_mo09.csv', 'ago_mo09.csv', 'dic_mo09.csv', 'abr_mo09.csv', 'jul_mo09.csv', 'may_mo09.csv', 'ene_mo09.csv', 'oct_mo09.csv']
# sep_mo09.csv
# Add sep_mo09.csv to data
# jun_mo09.csv
# Add jun_mo09.csv to data
# feb_mo09.csv
# Add feb_mo09.csv to data
# nov_mo09.csv
# Add nov_mo09.csv to data
# mar_mo09.csv
# Add mar_mo09.csv to data
# ago_mo09.csv
# Add ago_mo09.csv to data
# dic_mo09.csv
# Add dic_mo09.csv to data
# abr_mo09.csv
# Add abr_mo09.csv to data
# jul_mo09.csv
# Add jul_mo09.csv to data
# may_mo09.csv
# Add may_mo09.csv to data
# ene_mo09.csv
# Add ene_mo09.csv to data
# oct_mo09.csv
# Add oct_mo09.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio6 | [] | ['ago_mo06.csv', 'ene_mo06.csv', 'dic_mo06.csv', 'jul_mo06.csv', 'may_mo06.csv', 'sep_mo06.csv', 'nov_mo06.csv', 'mar_mo06.csv', 'jun_mo06.csv', 'oct_mo06.csv', 'feb_mo06.csv', 'abr_mo06.csv']
# ago_mo06.csv
# Add ago_mo06.csv to data
# ene_mo06.csv
# Add ene_mo06.csv to data
# dic_mo06.csv
# Add dic_mo06.csv to data
# jul_mo06.csv
# Add jul_mo06.csv to data
# may_mo06.csv
# Add may_mo06.csv to data
# sep_mo06.csv
# Add sep_mo06.csv to data
# nov_mo06.csv
# Add nov_mo06.csv to data
# mar_mo06.csv
# Add mar_mo06.csv to data
# jun_mo06.csv
# Add jun_mo06.csv to data
# oct_mo06.csv
# Add oct_mo06.csv to data
# feb_mo06.csv
# Add feb_mo06.csv to data
# abr_mo06.csv
# Add abr_mo06.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio22 | [] | ['jul_mo22.csv', 'may_mo22.csv', 'dic_mo22.csv', 'mar_mo22.csv', 'oct_mo22.csv', 'abr_mo22.csv', 'nov_mo22.csv', 'feb_mo22.csv', 'sep_mo22.csv', 'ago_mo22.csv', 'jun_mo22.csv', 'ene_mo22.csv']
# jul_mo22.csv
# Add jul_mo22.csv to data
# may_mo22.csv
# Add may_mo22.csv to data
# dic_mo22.csv
# Add dic_mo22.csv to data
# mar_mo22.csv
# Add mar_mo22.csv to data
# oct_mo22.csv
# Add oct_mo22.csv to data
# abr_mo22.csv
# Add abr_mo22.csv to data
# nov_mo22.csv
# Add nov_mo22.csv to data
# feb_mo22.csv
# Add feb_mo22.csv to data
# sep_mo22.csv
# Add sep_mo22.csv to data
# ago_mo22.csv
# Add ago_mo22.csv to data
# jun_mo22.csv
# Add jun_mo22.csv to data
# ene_mo22.csv
# Add ene_mo22.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio11 | [] | ['dic_mo11.csv', 'jul_mo11.csv', 'may_mo11.csv', 'ene_mo11.csv', 'nov_mo11.csv', 'mar_mo11.csv', 'sep_mo11.csv', 'jun_mo11.csv', 'ago_mo11.csv', 'feb_mo11.csv', 'abr_mo11.csv', 'oct_mo11.csv']
# dic_mo11.csv
# Add dic_mo11.csv to data
# jul_mo11.csv
# Add jul_mo11.csv to data
# may_mo11.csv
# Add may_mo11.csv to data
# ene_mo11.csv
# Add ene_mo11.csv to data
# nov_mo11.csv
# Add nov_mo11.csv to data
# mar_mo11.csv
# Add mar_mo11.csv to data
# sep_mo11.csv
# Add sep_mo11.csv to data
# jun_mo11.csv
# Add jun_mo11.csv to data
# ago_mo11.csv
# Add ago_mo11.csv to data
# feb_mo11.csv
# Add feb_mo11.csv to data
# abr_mo11.csv
# Add abr_mo11.csv to data
# oct_mo11.csv
# Add oct_mo11.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/.ipynb_checkpoints | [] | []
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio12 | [] | ['feb_mo12.csv', 'may_mo12.csv', 'ago_mo12.csv', 'ene_mo12.csv', 'abr_mo12.csv', 'sep_mo12.csv', 'nov_mo12.csv', 'jul_mo12.csv', 'jun_mo12.csv', 'mar_mo12.csv', 'oct_mo12.csv', 'dic_mo12.csv']
# feb_mo12.csv
# Add feb_mo12.csv to data
# may_mo12.csv
# Add may_mo12.csv to data
# ago_mo12.csv
# Add ago_mo12.csv to data
# ene_mo12.csv
# Add ene_mo12.csv to data
# abr_mo12.csv
# Add abr_mo12.csv to data
# sep_mo12.csv
# Add sep_mo12.csv to data
# nov_mo12.csv
# Add nov_mo12.csv to data
# jul_mo12.csv
# Add jul_mo12.csv to data
# jun_mo12.csv
# Add jun_mo12.csv to data
# mar_mo12.csv
# Add mar_mo12.csv to data
# oct_mo12.csv
# Add oct_mo12.csv to data
# dic_mo12.csv
# Add dic_mo12.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio17 | [] | ['mar_mo17.csv', 'ago_mo17.csv', 'jun_mo17.csv', 'jul_mo17.csv', 'feb_mo17.csv', 'dic_mo17.csv', 'abr_mo17.csv', 'may_mo17.csv', 'oct_mo17.csv', 'nov_mo17.csv', 'sep_mo17.csv', 'ene_mo17.csv']
# mar_mo17.csv
# Add mar_mo17.csv to data
# ago_mo17.csv
# Add ago_mo17.csv to data
# jun_mo17.csv
# Add jun_mo17.csv to data
# jul_mo17.csv
# Add jul_mo17.csv to data
# feb_mo17.csv
# Add feb_mo17.csv to data
# dic_mo17.csv
# Add dic_mo17.csv to data
# abr_mo17.csv
# Add abr_mo17.csv to data
# may_mo17.csv
# Add may_mo17.csv to data
# oct_mo17.csv
# Add oct_mo17.csv to data
# nov_mo17.csv
# Add nov_mo17.csv to data
# sep_mo17.csv
# Add sep_mo17.csv to data
# ene_mo17.csv
# Add ene_mo17.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio20 | [] | ['may_mo20.csv', 'feb_mo20.csv', 'oct_mo20.csv', 'jul_mo20.csv', 'ago_mo20.csv', 'jun_mo20.csv', 'sep_mo20.csv', 'mar_mo20.csv', 'abr_mo20.csv', 'nov_mo20.csv', 'dic_mo20.csv', 'ene_mo20.csv']
# may_mo20.csv
# Add may_mo20.csv to data
# feb_mo20.csv
# Add feb_mo20.csv to data
# oct_mo20.csv
# Add oct_mo20.csv to data
# jul_mo20.csv
# Add jul_mo20.csv to data
# ago_mo20.csv
# Add ago_mo20.csv to data
# jun_mo20.csv
# Add jun_mo20.csv to data
# sep_mo20.csv
# Add sep_mo20.csv to data
# mar_mo20.csv
# Add mar_mo20.csv to data
# abr_mo20.csv
# Add abr_mo20.csv to data
# nov_mo20.csv
# Add nov_mo20.csv to data
# dic_mo20.csv
# Add dic_mo20.csv to data
# ene_mo20.csv
# Add ene_mo20.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio16 | [] | ['ago_mo16.csv', 'ene_mo16.csv', 'dic_mo16.csv', 'jun_mo16.csv', 'sep_mo16.csv', 'oct_mo16.csv', 'nov_mo16.csv', 'mar_mo16.csv', 'abr_mo16.csv', 'may_mo16.csv', 'jul_mo16.csv', 'feb_mo16.csv']
# ago_mo16.csv
# Add ago_mo16.csv to data
# ene_mo16.csv
# Add ene_mo16.csv to data
# dic_mo16.csv
# Add dic_mo16.csv to data
# jun_mo16.csv
# Add jun_mo16.csv to data
# sep_mo16.csv
# Add sep_mo16.csv to data
# oct_mo16.csv
# Add oct_mo16.csv to data
# nov_mo16.csv
# Add nov_mo16.csv to data
# mar_mo16.csv
# Add mar_mo16.csv to data
# abr_mo16.csv
# Add abr_mo16.csv to data
# may_mo16.csv
# Add may_mo16.csv to data
# jul_mo16.csv
# Add jul_mo16.csv to data
# feb_mo16.csv
# Add feb_mo16.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio10 | [] | ['oct_mo10.csv', 'sep_mo10.csv', 'ene_mo10.csv', 'ago_mo10.csv', 'jun_mo10.csv', 'abr_mo10.csv', 'dic_mo10.csv', 'jul_mo10.csv', 'feb_mo10.csv', 'nov_mo10.csv', 'may_mo10.csv', 'mar_mo10.csv']
# oct_mo10.csv
# Add oct_mo10.csv to data
# sep_mo10.csv
# Add sep_mo10.csv to data
# ene_mo10.csv
# Add ene_mo10.csv to data
# ago_mo10.csv
# Add ago_mo10.csv to data
# jun_mo10.csv
# Add jun_mo10.csv to data
# abr_mo10.csv
# Add abr_mo10.csv to data
# dic_mo10.csv
# Add dic_mo10.csv to data
# jul_mo10.csv
# Add jul_mo10.csv to data
# feb_mo10.csv
# Add feb_mo10.csv to data
# nov_mo10.csv
# Add nov_mo10.csv to data
# may_mo10.csv
# Add may_mo10.csv to data
# mar_mo10.csv
# Add mar_mo10.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio2 | [] | ['mar_mo02.csv', 'ago_mo02.csv', 'jun_mo02.csv', 'oct_mo02.csv', 'nov_mo02.csv', 'may_mo02.csv', 'abr_mo02.csv', 'ene_mo02.csv', 'feb_mo02.csv', 'jul_mo02.csv', 'sep_mo02.csv', 'dic_mo02.csv']
# mar_mo02.csv
# Add mar_mo02.csv to data
# ago_mo02.csv
# Add ago_mo02.csv to data
# jun_mo02.csv
# Add jun_mo02.csv to data
# oct_mo02.csv
# Add oct_mo02.csv to data
# nov_mo02.csv
# Add nov_mo02.csv to data
# may_mo02.csv
# Add may_mo02.csv to data
# abr_mo02.csv
# Add abr_mo02.csv to data
# ene_mo02.csv
# Add ene_mo02.csv to data
# feb_mo02.csv
# Add feb_mo02.csv to data
# jul_mo02.csv
# Add jul_mo02.csv to data
# sep_mo02.csv
# Add sep_mo02.csv to data
# dic_mo02.csv
# Add dic_mo02.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio4 | [] | ['sep_mo04.csv', 'jun_mo04.csv', 'oct_mo04.csv', 'may_mo04.csv', 'mar_mo04.csv', 'ago_mo04.csv', 'jul_mo04.csv', 'dic_mo04.csv', 'nov_mo04.csv', 'feb_mo04.csv', 'abr_mo04.csv', 'ene_mo04.csv']
# sep_mo04.csv
# Add sep_mo04.csv to data
# jun_mo04.csv
# Add jun_mo04.csv to data
# oct_mo04.csv
# Add oct_mo04.csv to data
# may_mo04.csv
# Add may_mo04.csv to data
# mar_mo04.csv
# Add mar_mo04.csv to data
# ago_mo04.csv
# Add ago_mo04.csv to data
# jul_mo04.csv
# Add jul_mo04.csv to data
# dic_mo04.csv
# Add dic_mo04.csv to data
# nov_mo04.csv
# Add nov_mo04.csv to data
# feb_mo04.csv
# Add feb_mo04.csv to data
# abr_mo04.csv
# Add abr_mo04.csv to data
# ene_mo04.csv
# Add ene_mo04.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio8 | [] | ['jul_mo08.csv', 'may_mo08.csv', 'ago_mo08.csv', 'abr_mo08.csv', 'sep_mo08.csv', 'oct_mo08.csv', 'jun_mo08.csv', 'nov_mo08.csv', 'feb_mo08.csv', 'dic_mo08.csv', 'ene_mo08.csv', 'mar_mo08.csv']
# jul_mo08.csv
# Add jul_mo08.csv to data
# may_mo08.csv
# Add may_mo08.csv to data
# ago_mo08.csv
# Add ago_mo08.csv to data
# abr_mo08.csv
# Add abr_mo08.csv to data
# sep_mo08.csv
# Add sep_mo08.csv to data
# oct_mo08.csv
# Add oct_mo08.csv to data
# jun_mo08.csv
# Add jun_mo08.csv to data
# nov_mo08.csv
# Add nov_mo08.csv to data
# feb_mo08.csv
# Add feb_mo08.csv to data
# dic_mo08.csv
# Add dic_mo08.csv to data
# ene_mo08.csv
# Add ene_mo08.csv to data
# mar_mo08.csv
# Add mar_mo08.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio7 | [] | ['sep_mo07.csv', 'nov_mo07.csv', 'may_mo07.csv', 'jun_mo07.csv', 'feb_mo07.csv', 'dic_mo07.csv', 'abr_mo07.csv', 'oct_mo07.csv', 'ago_mo07.csv', 'ene_mo07.csv', 'mar_mo07.csv', 'jul_mo07.csv']
# sep_mo07.csv
# Add sep_mo07.csv to data
# nov_mo07.csv
# Add nov_mo07.csv to data
# may_mo07.csv
# Add may_mo07.csv to data
# jun_mo07.csv
# Add jun_mo07.csv to data
# feb_mo07.csv
# Add feb_mo07.csv to data
# dic_mo07.csv
# Add dic_mo07.csv to data
# abr_mo07.csv
# Add abr_mo07.csv to data
# oct_mo07.csv
# Add oct_mo07.csv to data
# ago_mo07.csv
# Add ago_mo07.csv to data
# ene_mo07.csv
# Add ene_mo07.csv to data
# mar_mo07.csv
# Add mar_mo07.csv to data
# jul_mo07.csv
# Add jul_mo07.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio19 | [] | ['abr_mo19.csv', 'ene_mo19.csv', 'ago_mo19.csv', 'sep_mo19.csv', 'may_mo19.csv', 'feb_mo19.csv', 'dic_mo19.csv', 'jun_mo19.csv', 'jul_mo19.csv', 'oct_mo19.csv', 'nov_mo19.csv', 'mar_mo19.csv']
# abr_mo19.csv
# Add abr_mo19.csv to data
# ene_mo19.csv
# Add ene_mo19.csv to data
# ago_mo19.csv
# Add ago_mo19.csv to data
# sep_mo19.csv
# Add sep_mo19.csv to data
# may_mo19.csv
# Add may_mo19.csv to data
# feb_mo19.csv
# Add feb_mo19.csv to data
# dic_mo19.csv
# Add dic_mo19.csv to data
# jun_mo19.csv
# Add jun_mo19.csv to data
# jul_mo19.csv
# Add jul_mo19.csv to data
# oct_mo19.csv
# Add oct_mo19.csv to data
# nov_mo19.csv
# Add nov_mo19.csv to data
# mar_mo19.csv
# Add mar_mo19.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio21 | [] | ['jun_mo21.csv', 'nov_mo21.csv', 'sep_mo21.csv', 'abr_mo21.csv', 'may_mo21.csv', 'ene_mo21.csv', 'oct_mo21.csv', 'jul_mo21.csv', 'dic_mo21.csv', 'ago_mo21.csv', 'feb_mo21.csv', 'mar_mo21.csv']
# jun_mo21.csv
# Add jun_mo21.csv to data
# nov_mo21.csv
# Add nov_mo21.csv to data
# sep_mo21.csv
# Add sep_mo21.csv to data
# abr_mo21.csv
# Add abr_mo21.csv to data
# may_mo21.csv
# Add may_mo21.csv to data
# ene_mo21.csv
# Add ene_mo21.csv to data
# oct_mo21.csv
# Add oct_mo21.csv to data
# jul_mo21.csv
# Add jul_mo21.csv to data
# dic_mo21.csv
# Add dic_mo21.csv to data
# ago_mo21.csv
# Add ago_mo21.csv to data
# feb_mo21.csv
# Add feb_mo21.csv to data
# mar_mo21.csv
# Add mar_mo21.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio1 | [] | ['ago_mo01.csv', 'may_mo01.csv', 'ene_mo01.csv', 'feb_mo01.csv', 'nov_mo01.csv', 'jul_mo01.csv', 'mar_mo01.csv', 'oct_mo01.csv', 'jun_mo01.csv', 'dic_mo01.csv', 'sep_mo01.csv', 'abr_mo01.csv']
# ago_mo01.csv
# Add ago_mo01.csv to data
# may_mo01.csv
# Add may_mo01.csv to data
# ene_mo01.csv
# Add ene_mo01.csv to data
# feb_mo01.csv
# Add feb_mo01.csv to data
# nov_mo01.csv
# Add nov_mo01.csv to data
# jul_mo01.csv
# Add jul_mo01.csv to data
# mar_mo01.csv
# Add mar_mo01.csv to data
# oct_mo01.csv
# Add oct_mo01.csv to data
# jun_mo01.csv
# Add jun_mo01.csv to data
# dic_mo01.csv
# Add dic_mo01.csv to data
# sep_mo01.csv
# Add sep_mo01.csv to data
# abr_mo01.csv
# Add abr_mo01.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio14 | [] | ['sep_mo14.csv', 'nov_mo14.csv', 'may_mo14.csv', 'jun_mo14.csv', 'abr_mo14.csv', 'dic_mo14.csv', 'feb_mo14.csv', 'mar_mo14.csv', 'ago_mo14.csv', 'jul_mo14.csv', 'ene_mo14.csv', 'oct_mo14.csv']
# sep_mo14.csv
# Add sep_mo14.csv to data
# nov_mo14.csv
# Add nov_mo14.csv to data
# may_mo14.csv
# Add may_mo14.csv to data
# jun_mo14.csv
# Add jun_mo14.csv to data
# abr_mo14.csv
# Add abr_mo14.csv to data
# dic_mo14.csv
# Add dic_mo14.csv to data
# feb_mo14.csv
# Add feb_mo14.csv to data
# mar_mo14.csv
# Add mar_mo14.csv to data
# ago_mo14.csv
# Add ago_mo14.csv to data
# jul_mo14.csv
# Add jul_mo14.csv to data
# ene_mo14.csv
# Add ene_mo14.csv to data
# oct_mo14.csv
# Add oct_mo14.csv to data
# Delete calidad_aire_madrid
# calidad_aire_madrid - calidad_aire_madrid/Anio23 | [] | ['sep_mo23.csv', 'ene_mo23.csv', 'nov_mo23.csv', 'jul_mo23.csv', 'oct_mo23.csv', 'ago_mo23.csv', 'abr_mo23.csv', 'may_mo23.csv', 'feb_mo23.csv', 'jun_mo23.csv', 'mar_mo23.csv', 'dic_mo23.csv']
# sep_mo23.csv
# Add sep_mo23.csv to data
# ene_mo23.csv
# Add ene_mo23.csv to data
# nov_mo23.csv
# Add nov_mo23.csv to data
# jul_mo23.csv
# Add jul_mo23.csv to data
# oct_mo23.csv
# Add oct_mo23.csv to data
# ago_mo23.csv
# Add ago_mo23.csv to data
# abr_mo23.csv
# Add abr_mo23.csv to data
# may_mo23.csv
# Add may_mo23.csv to data
# feb_mo23.csv
# Add feb_mo23.csv to data
# jun_mo23.csv
# Add jun_mo23.csv to data
# mar_mo23.csv
# Add mar_mo23.csv to data
# dic_mo23.csv
# Add dic_mo23.csv to data
# Delete calidad_aire_madrid
# Could not download 2001. Output_dir: calidad_aire_madrid

# %%
print(all_data.shape)
all_data.head()
# Out:
# (14117970, 56)
#    PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 0         28         79         4         1  28079004_1_38  2024    2    1
# 1         28         79         4         1  28079004_1_38  2024    2    2
# 2         28         79         4         1  28079004_1_38  2024    2    3
# 3         28         79         4         1  28079004_1_38  2024    2    4
# 4         28         79         4         1  28079004_1_38  2024    2    5
#
#    H01 V01  ...  H20 V20  H21 V21  H22 V22  H23 V23  H24 V24
# 0  1.0   V  ...  6.0   V  6.0   V  4.0   V  4.0   V  3.0   V
# 1  3.0   V  ...  4.0   V  5.0   V  3.0   V  2.0   V  2.0   V
# 2  1.0   V  ...  3.0   V  4.0   V  3.0   V  2.0   V  2.0   V
# 3  1.0   V  ...  2.0   V  3.0   V  6.0   V  3.0   V  2.0   V
# 4  1.0   V  ...  5.0   V  4.0   V  4.0   V  5.0   V  4.0   V
#
# [5 rows x 56 columns]

# %%
22*24*365
# Out:
# 192720

# %%
set(all_data['ANO'])
# Out:
# {2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022,
#  2023,
#  2024}

# %%
all_data.to_csv("calidad_aire_madrid_2001_2024.csv", index=False, sep  = ";")

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from IPython.display import display

# %% [markdown]
# ETL

# %%
filename = 'calidad_aire_madrid_2001_2024'
filetype = '.csv'
filepath = './'+filename+filetype
filepath_processed = os.path.expanduser('~/data/'+'horario_ensanche_vallecas'+filetype)
df = pd.read_csv(filepath, sep = ";")

# %%
df.columns
# Out:
# Index(['PROVINCIA', 'MUNICIPIO', 'ESTACION', 'MAGNITUD', 'PUNTO_MUESTREO',
#        'ANO', 'MES', 'DIA', 'H01', 'V01', 'H02', 'V02', 'H03', 'V03', 'H04',
#        'V04', 'H05', 'V05', 'H06', 'V06', 'H07', 'V07', 'H08', 'V08', 'H09',
#        'V09', 'H10', 'V10', 'H11', 'V11', 'H12', 'V12', 'H13', 'V13', 'H14',
#        'V14', 'H15', 'V15', 'H16', 'V16', 'H17', 'V17', 'H18', 'V18', 'H19',
#        'V19', 'H20', 'V20', 'H21', 'V21', 'H22', 'V22', 'H23', 'V23', 'H24',
#        'V24'],
#       dtype='object')

# %%
display(df.head())
# Out:
#    PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  DIA  \
# 0         28         79         4         1  28079004_1_38  2024    2    1
# 1         28         79         4         1  28079004_1_38  2024    2    2
# 2         28         79         4         1  28079004_1_38  2024    2    3
# 3         28         79         4         1  28079004_1_38  2024    2    4
# 4         28         79         4         1  28079004_1_38  2024    2    5
#
#    H01 V01  ...  H20 V20  H21 V21  H22 V22  H23 V23  H24 V24
# 0  1.0   V  ...  6.0   V  6.0   V  4.0   V  4.0   V  3.0   V
# 1  3.0   V  ...  4.0   V  5.0   V  3.0   V  2.0   V  2.0   V
# 2  1.0   V  ...  3.0   V  4.0   V  3.0   V  2.0   V  2.0   V
# 3  1.0   V  ...  2.0   V  3.0   V  6.0   V  3.0   V  2.0   V
# 4  1.0   V  ...  5.0   V  4.0   V  4.0   V  5.0   V  4.0   V
#
# [5 rows x 56 columns]

# %% [markdown]
# ## Organize data and set timestamp

# %%
df_reorganized = pd.DataFrame()
for hour in range(1, 25):
    hour_str = f'H{hour:02d}'
    validation_str = f'V{hour:02d}'
    df_hour = df[['ANO', 'MES', 'DIA', 'ESTACION', 'MAGNITUD', hour_str, validation_str]].copy()
    df_hour.columns = ['year', 'month', 'day', 'station', 'magnitude', 'value', 'validation']
    df_hour['hour'] = int(hour)
    df_reorganized = pd.concat([df_reorganized, df_hour])
display(df_reorganized.head())
# Out:
#    year  month  day  station  magnitude  value validation  hour
# 0  2024      2    1        4          1    1.0          V     1
# 1  2024      2    2        4          1    3.0          V     1
# 2  2024      2    3        4          1    1.0          V     1
# 3  2024      2    4        4          1    1.0          V     1
# 4  2024      2    5        4          1    1.0          V     1

# %%
df_reorganized['timestamp'] = pd.to_datetime(df_reorganized[['year', 'month', 'day', 'hour']])

# %%
df_reorganized.set_index('timestamp', inplace=True)

# %%
df_reorganized.drop(columns=['year', 'month', 'day', 'hour', 'validation'], inplace=True)

# %%
display(df_reorganized.head())
# Out:
#                      station  magnitude  value
# timestamp
# 2024-02-01 01:00:00        4          1    1.0
# 2024-02-02 01:00:00        4          1    3.0
# 2024-02-03 01:00:00        4          1    1.0
# 2024-02-04 01:00:00        4          1    1.0
# 2024-02-05 01:00:00        4          1    1.0

# %% [markdown]
# ## Select Ensanche de Vallecas

# %%
df_ensanche = df_reorganized[df_reorganized['station'] == 58].copy()
df_ensanche.drop(columns = ['station'], inplace = True)
display(df_ensanche.head())
# Out:
#                      magnitude  value
# timestamp
# 2024-02-01 01:00:00          7    4.0
# 2024-02-02 01:00:00          7    2.0
# 2024-02-03 01:00:00          7    3.0
# 2024-02-04 01:00:00          7    2.0
# 2024-02-05 01:00:00          7    2.0

# %% [markdown]
# ### Filter magnitudes
# (in this case, all available magnituded are selected)

# %%
magnitudes = [7, 8, 12, 14]
df_ensanche_filtered = df_ensanche[df_ensanche['magnitude'].isin(magnitudes)]
#display(df_ensanche_filtered.head())
df_ensanche_pivot = df_ensanche_filtered.pivot_table(index='timestamp', columns='magnitude', values='value')
df_ensanche_pivot.columns = ['NO', 'NO2', 'NOx', 'O3']
display(df_ensanche_pivot.head())
# Out:
#                       NO  NO2  NOx   O3
# timestamp
# 2009-11-30 01:00:00  0.0  0.0  0.0  0.0
# 2009-11-30 02:00:00  0.0  0.0  0.0  0.0
# 2009-11-30 03:00:00  0.0  0.0  0.0  0.0
# 2009-11-30 04:00:00  0.0  0.0  0.0  0.0
# 2009-11-30 05:00:00  0.0  0.0  0.0  0.0

# %% [markdown]
# ### Save as CSV

# %%
print(filepath_processed)
df_ensanche_pivot.to_csv(filepath_processed)
# Out:
# /home/macu/data/horario_ensanche_vallecas.csv

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Load the data

# %%
# Leer los datos preparados
df = pd.read_csv(filepath_processed, index_col='timestamp', parse_dates=True)

# %%
df.head()
df.shape
# Out:
# (127800, 4)

# %% [markdown]
# ### Select a magnitude for the analysis

# %%
magnitudes = df.columns
print(magnitudes)
# Out:
# Index(['NO', 'NO2', 'NOx', 'O3'], dtype='object')

# %%
magnitude = 'NO'
ts = df[magnitude]

# %% [markdown]
# ### Decompose the time series to check seasonality

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# #### Daily patterns

# %%
decomposition = seasonal_decompose(ts, model='additive', period=24)

# %%
fig, axes = plt.subplots(4, 1, figsize=(15, 10), sharex=True)
decomposition.observed.plot(ax=axes[0], legend=False)
axes[0].set_ylabel('Observed')
decomposition.trend.plot(ax=axes[1], legend=False)
axes[1].set_ylabel('Trend')
decomposition.seasonal.plot(ax=axes[2], legend=False)
axes[2].set_ylabel('Seasonal')
decomposition.resid.plot(ax=axes[3], legend=False)
axes[3].set_ylabel('Residual')
plt.show()

# %% [markdown]
# #### Weekly patterns

# %%
decomposition = seasonal_decompose(ts, model='additive', period=168)
fig, axes = plt.subplots(4, 1, figsize=(15, 10), sharex=True)
decomposition.observed.plot(ax=axes[0], legend=False)
axes[0].set_ylabel('Observed')
decomposition.trend.plot(ax=axes[1], legend=False)
axes[1].set_ylabel('Trend')
decomposition.seasonal.plot(ax=axes[2], legend=False)
axes[2].set_ylabel('Seasonal')
decomposition.resid.plot(ax=axes[3], legend=False)
axes[3].set_ylabel('Residual')
plt.show()

# %% [markdown]
# #### Monthly patterns

# %%
decomposition = seasonal_decompose(ts, model='additive', period=720)
fig, axes = plt.subplots(4, 1, figsize=(15, 10), sharex=True)
decomposition.observed.plot(ax=axes[0], legend=False)
axes[0].set_ylabel('Observed')
decomposition.trend.plot(ax=axes[1], legend=False)
axes[1].set_ylabel('Trend')
decomposition.seasonal.plot(ax=axes[2], legend=False)
axes[2].set_ylabel('Seasonal')
decomposition.resid.plot(ax=axes[3], legend=False)
axes[3].set_ylabel('Residual')
plt.show()

# %% [markdown]
# #### Zooming

# %%
# Descomponer la serie temporal para verificar la estacionalidad semanal y mensual
decomposition_weekly = seasonal_decompose(ts, model='additive', period=168)
decomposition_monthly = seasonal_decompose(ts, model='additive', period=720)

# Definir el rango para hacer zoom (por ejemplo, un mes específico)
start_date = '2023-01-01'
end_date = '2023-01-31'

# Filtrar la serie temporal original y las componentes estacionales para el rango especificado
ts_zoom = ts[start_date:end_date]
seasonal_weekly_zoom = decomposition_weekly.seasonal[start_date:end_date]
seasonal_monthly_zoom = decomposition_monthly.seasonal[start_date:end_date]

# Graficar la serie temporal original y las componentes estacionales con zoom
fig, axes = plt.subplots(3, 1, figsize=(15, 10), sharex=True)

# Serie temporal original
ts_zoom.plot(ax=axes[0])
axes[0].set_ylabel('Original')
axes[0].set_title('Original Time Series and Seasonal Components')

# Componente estacional semanal
seasonal_weekly_zoom.plot(ax=axes[1])
axes[1].set_ylabel('Seasonal (Weekly)')

# Componente estacional mensual
seasonal_monthly_zoom.plot(ax=axes[2])
axes[2].set_ylabel('Seasonal (Monthly)')

plt.show()

# %%
from nbdev import *

# %%
#| hide
import sys
sys.path.append("..")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Baseline Models
#
# > This notebook tries generate baseline models to evaluate if DCAE models have a good performance or nor

# %%
#| hide
from fastcore import test
import pandas as pd
import numpy as np

# %%
#| hide
from dvats.load import *
from dvats.dr import *
from dvats.visualization import *
from dvats.utils import *
from tensorflow.keras.optimizers import Adam
#from torch.optim import Adam
import wandb
from wandb.keras import WandbCallback #-- not necesary without keras
from yaml import load, FullLoader
from fastcore.utils import Path
from datetime import datetime
import pickle

# %% [markdown]
# Create a run to save the models (job_type = "baseline_models")

# %%
#| hide
run_baseline = wandb.init(entity = "pacmel",
                      project="timecluster-extension",
                      job_type='baseline_models',
                      allow_val_change=True,
                      resume=False)
config = wandb.config  # Object for storing hyperparameters
# Out:
# Tracking run with wandb version 0.14.2
# Run data is saved locally in <code>/home/macu/work/wandb/run-20240723_145618-i6da9pmc</code>
# Syncing run <strong><a href='https://wandb.ai/mi-santamaria/deepvats/runs/i6da9pmc' target="_blank">glad-pyramid-1327</a></strong> to <a href='https://wandb.ai/mi-santamaria/deepvats' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mi-santamaria/deepvats' target="_blank">https://wandb.ai/mi-santamaria/deepvats</a>
#  View run at <a href='https://wandb.ai/mi-santamaria/deepvats/runs/i6da9pmc' target="_blank">https://wandb.ai/mi-santamaria/deepvats/runs/i6da9pmc</a>

# %% [markdown]
# ## Load the datasets

# %%
artifact_name_and_version = 'JNK:train_10days'

# %%
ds_train_artifact = run_baseline.use_artifact(artifact_name_and_version)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/apis/public.py:957, in Api.artifact(self, name, type)
#     956 entity, project, artifact_name = self._parse_artifact_path(name)
# --> 957 artifact = Artifact(self.client, entity, project, artifact_name)
#     958 if type is not None and artifact.type != type:
#
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/apis/public.py:4355, in Artifact.__init__(self, client, entity, project, name, attrs)
#    4354 if self._attrs is None:
# -> 4355     self._load()
#    4357 # The entity and project above are taken from the passed-in artifact version path
#    4358 # so if the user is pulling an artifact version from an artifact portfolio, the entity/project
#    4359 # of that portfolio may be different than the birth entity/project of the artifact version.
#
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/apis/public.py:5082, in Artifact._load(self)
#    5077 if (
#    5078     response is None
#    5079     or response.get("project") is None
#    5080     or response["project"].get("artifact") is None
#    5081 ):
# -> 5082     raise ValueError(
#    5083         'Project %s/%s does not contain artifact: "%s"'
#    5084         % (self.entity, self.project, self._artifact_name)
#    5085     )
#    5086 self._attrs = response["project"]["artifact"]
#
# ValueError: Project mi-santamaria/deepvats does not contain artifact: "JNK:train_10days"
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ds_train_artifact = run_baseline.use_artifact(artifact_name_and_version)
#
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:344, in _run_decorator._noop_on_finish.<locals>.decorator_fn.<locals>.wrapper_fn(self, *args, **kwargs)
#     341 @functools.wraps(func)
#     342 def wrapper_fn(self: Type["Run"], *args: Any, **kwargs: Any) -> Any:
#     343     if not getattr(self, "_is_finished", False):
# --> 344         return func(self, *args, **kwargs)
#     346     default_message = (
#     347         f"Run ({self.id}) is finished. The call to `{func.__name__}` will be ignored. "
#     348         f"Please make sure that you are using an active run."
#     349     )
#     350     resolved_message = message or default_message
#
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:334, in _run_decorator._attach.<locals>.wrapper(self, *args, **kwargs)
#     332         raise e
#     333     cls._is_attaching = ""
# --> 334 return func(self, *args, **kwargs)
#
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:2675, in Run.use_artifact(self, artifact_or_name, type, aliases, use_as)
#    2673     name = artifact_or_name
#    2674 public_api = self._public_api()
# -> 2675 artifact = public_api.artifact(type=type, name=name)
#    2676 if type is not None and type != artifact.type:
#    2677     raise ValueError(
#    2678         "Supplied type {} does not match type {} of artifact {}".format(
#    2679             type, artifact.type, artifact.name
#    2680         )
#    2681     )
#
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/apis/normalize.py:87, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      85     raise
#      86 else:
# ---> 87     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/apis/normalize.py:41, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      39 message = "Whoa, you found a bug."
#      40 try:
# ---> 41     return func(*args, **kwargs)
#      42 except requests.HTTPError as error:
#      43     errors = parse_backend_error_messages(error.response)
#
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/apis/public.py:957, in Api.artifact(self, name, type)
#     955     raise ValueError("You must specify name= to fetch an artifact.")
#     956 entity, project, artifact_name = self._parse_artifact_path(name)
# --> 957 artifact = Artifact(self.client, entity, project, artifact_name)
#     958 if type is not None and artifact.type != type:
#     959     raise ValueError(
#     960         f"type {type} specified but this artifact is of type {artifact.type}"
#     961     )
#
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/apis/public.py:4355, in Artifact.__init__(self, client, entity, project, name, attrs)
#    4353 self._attrs = attrs
#    4354 if self._attrs is None:
# -> 4355     self._load()
#    4357 # The entity and project above are taken from the passed-in artifact version path
#    4358 # so if the user is pulling an artifact version from an artifact portfolio, the entity/project
#    4359 # of that portfolio may be different than the birth entity/project of the artifact version.
#    4360 self._birth_project = (
#    4361     self._attrs.get("artifactType", {}).get("project", {}).get("name")
#    4362 )
#
# File /usr/local/share/miniconda3/envs/env/lib/python3.10/site-packages/wandb/apis/public.py:5082, in Artifact._load(self)
#    5074         raise ValueError(
#    5075             'Attempted to fetch artifact without alias (e.g. "<artifact_name>:v3" or "<artifact_name>:latest")'
#    5076         )
#    5077 if (
#    5078     response is None
#    5079     or response.get("project") is None
#    5080     or response["project"].get("artifact") is None
#    5081 ):
# -> 5082     raise ValueError(
#    5083         'Project %s/%s does not contain artifact: "%s"'
#    5084         % (self.entity, self.project, self._artifact_name)
#    5085     )
#    5086 self._attrs = response["project"]["artifact"]
#    5087 return self._attrs
#
# CommError: Project mi-santamaria/deepvats does not contain artifact: "JNK:train_10days"

# %%
# parameters (uncomment to override the yaml file)
config.update(
    {
          'ds_train_artifact_type': ds_train_artifact.type,
          'ds_train_artifact_name': ds_train_artifact.name,
          'ds_train_artifact_digest': ds_train_artifact.digest,
    }, 
    allow_val_change=True)
ds_train_artifact.type, ds_train_artifact.name, ds_train_artifact.digest

# %%
df_train = ds_train_artifact.to_df()

# %%
df_train.head(1)

# %% [markdown]
# ## Train

# %% [markdown]
# ### Sliding window features

# %%
config.w = ifnone(config.get('w'), 48)
config.stride = ifnone(config.get('stride'), 1)
config.t = ifnone(config.get('t'), 0)

# %%
# parameters (uncomment to override the yaml file)
config.update({
    'w': config.w,
    'stride': config.stride,
    't': config.t  # TODO: Not supported yet
    }, allow_val_change=True)

# %%
test.equals(config.w % 12, 0)

# %%
input_data = df_slicer(df_train, w=config.w, s=config.stride)

# %%
data_test = input_data#Take 10 windows data_test[0:10,:,:]

# %%
data_test.shape

# %%
#| export utils
def baseline_model_predictor(input_array, operation = "mean"):
    " Perform an arithmetic operation (median or average) on a three-dimensional numpy array from df_slicer"
    # Calculate mean/median for each window in the dataset
    if operation == "mean":
        prediction = np.mean(input_array,axis=1)
    elif operation == "median":
        prediction = np.median(input_array,axis=1)
    # Generate an output numpy array with the same size that input_array with
    # baseline predictions
    # Create a 3-d numpy array with ones
    output_array = np.ones(input_array.shape)
    # Multiply it by the prediction array, with a new dimension in axis 1
    output_array = output_array * np.expand_dims(prediction, axis=1)
    return output_array

# %%
baseline_type = "median"

# %%
y_pred = baseline_model_predictor(data_test, baseline_type)

# %%
y_pred.shape

# %%
config.update({
        'baseline_type': baseline_type
    })

# %%
# Input and output have the same shape
assert y_pred.shape == data_test.shape

# %%
#| export utils
import tensorflow as tf
def get_windows_mse(predictions, original_data):
    " Function that calculates the mse for each of the windows in which an auto-encoder model has made a prediction."
    # Test that dimensions are correct.
    assert predictions.shape == original_data.shape
    # Create a mse object
    mse = tf.keras.losses.MeanSquaredError(
        reduction=tf.keras.losses.Reduction.NONE)
    # We need to adapt the axes to calculate the mse in the manner we want.
    prediction_swaped = np.swapaxes(predictions,1,2)
    original_data_swaped = np.swapaxes(original_data,1,2)
    # Calculate mses
    windows_mse = mse(original_data_swaped, prediction_swaped).numpy()
    
    return windows_mse

# %%
# %%time
windows_mse = get_windows_mse(y_pred,data_test)

# %%
windows_mse.shape

# %% [markdown]
# MSE per time series

# %%
windows_mse.mean(axis=0)

# %% [markdown]
# Total MSE:

# %%
windows_mse.mean()

# %% [markdown]
# Log results on wandb:

# %%
run_baseline.log({
    'mse_overall': windows_mse.mean(),
    'mse_signal': windows_mse.mean(axis=0), # MSE of each variable
    'mse_raw': windows_mse # Raw mse. It has the mse for each window and signal
})

# %% [markdown]
# Plot figure to visualize MSE per variable:

# %%
import matplotlib.pyplot as plt

plt.bar(list(df_train.columns),  windows_mse.mean(axis=0), align='center', alpha=0.5)
plt.xticks(list(df_train.columns), rotation='vertical')
plt.ylabel('MSE')
plt.title('variable')


wandb.log({"mse_signal_plot": plt})

# %%
run_baseline.finish()

# %% [markdown]
# It proves that `get_windows_mse()` is working correctly compared to the sklearn function. This check is done because the function is swapped, and it is convenient that the results are the same regardless of the method used.

# %%
# %%time
from sklearn.metrics import mean_squared_error
rme_sklearn = [0]* y_pred.shape[2]
for i in range(0,y_pred.shape[2]):
    y_pred_sel = y_pred[:,:,i]
    test_sel = data_test[:,:,i]
    rme_sklearn[i] = mean_squared_error(test_sel,y_pred_sel)

# %%
rme_sklearn_round = np.around(rme_sklearn, decimals=3)
rme_keras_round = np.around(windows_mse.mean(axis=0),decimals=3)

# %%
test.all_equal(rme_sklearn_round, rme_keras_round)
